# %%
import numpy as np

import dolfinx

from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log,default_scalar_type
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem,LinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import XDMFFile, VTXWriter
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional , gt, dx, inner, derivative, dot, ln, split,TestFunction,indices,as_tensor)
from basix.ufl import element, mixed_element, quadrature_element
from datetime import datetime, timedelta
from dolfinx.plot import vtk_mesh
from dolfinx.fem.petsc import  assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc,create_matrix, create_vector
import basix
import pyvista
pyvista.set_jupyter_backend('client')

from ElasticPlasticity.Plastic_material import Plastic_Material
from ElasticPlasticity.Plastic_Visibility import Problem_Saver
from ElasticPlasticity.Plasticity_Funcs import *
from ElasticPlasticity.Plasticity_Problem import Plastic_Problem_Def

# %%
problem_name = "Plastic Tensile Test Traction"
# Geometric parameters
geom = {"longside" : 100.0,     # mm
        "side" : 10.0,      # mm
        "num_elements" : 3,    # size of a cell
        }


# Mechanicals parameters
mech = {"E" : 100e3,    # MPa
        "nu" : 0.3,     #       
        "sig0" : 100.0,  # MPa
        "H" : 1250.0, # MPa
        "r" : 1.0,
        "Y_s" :300.0,#mpa
        "C" : 60.0e3,
        "gamma":400.0
        
        }


# Study parameters
stud = {"deg_u" : 1,    # Interpolation of u
        "deg_strain_quad" : 2,  # Interpolation of sig, eps, p
        }

load_steps  = {
        "N_incr" : 60,  # Number of load steps
        "max_disp" : 1.0 # Maximal displacemen
        }

# %% [markdown]
# # Domain and Boundary Definition

# %%
domain = mesh.create_box(MPI.COMM_WORLD,[[0.0,0.0,0.0],[geom["longside"],geom["side"],geom["side"]]],[geom["num_elements"]*10,geom["num_elements"],geom["num_elements"]])


def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], geom["longside"])
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], geom["side"])
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], geom["side"])

boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

facet_indices, facet_markers = [], []
fdim = domain.topology.dim - 1
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator)
    facet_indices.append(facets)
    facet_markers.append(np.full_like(facets, marker))

facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
mat = Plastic_Material(domain = domain,**mech)
plastic_problem = Plastic_Problem_Def(domain,mat,facet_tags=facet_tag,**stud)

# %% [markdown]
# # Boundary Conditions

# %%
from json import load


left_facets = facet_tag.find(1)

right_facets = facet_tag.find(2)


top_facets = facet_tag.find(3)
side_facets = facet_tag.find(5)
fdim = domain.topology.dim - 1
domain.topology.create_connectivity(fdim, domain.topology.dim)
disp = Constant(domain,0.0)

left_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(0), fdim, left_facets)
top_dof_y = fem.locate_dofs_topological(plastic_problem.V.sub(1), fdim, top_facets)
top_dof_z = fem.locate_dofs_topological(plastic_problem.V.sub(2), fdim, side_facets)
right_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(0),fdim, right_facets)

sym_bottom = fem.dirichletbc(0.0, left_dofs_x, plastic_problem.V.sub(0))
sym_left = fem.dirichletbc(disp, right_dofs_x, plastic_problem.V.sub(0))

sym_top = fem.dirichletbc(0.0, top_dof_z, plastic_problem.V.sub(1))
sym_side = fem.dirichletbc(0.0, top_dof_y, plastic_problem.V.sub(2))

bcs = [sym_bottom,sym_top,sym_side]

#bcs = [sym_bottom, sym_left]

disp = Constant(domain,(0.0,0.0,0.0))


def F_ext(t):
    arr = np.zeros((3,))
    arr[0] = t*200.0
    return arr

# %%
plastic_problem._init_linear_problem([(-disp,plastic_problem.ds(2))])

# %% [markdown]
# # Data for Plotting

# %%
E_n = eps(plastic_problem.u)
E_p = plastic_problem.E_p

Stress_Point = mat.sigma(E_n - E_p)
area= Constant(domain,(geom["side"]*geom["side"]))
Elastic = Function(plastic_problem.V_scal)

project(Stress_Point[0,0],Elastic)
engineeringStress= fem.form(Elastic/area*plastic_problem.ds(2)) #P22/area*ds


pointForStress = [geom["longside"],5,5]

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, np.array(pointForStress))
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates,  np.array(pointForStress))

# %%
saver = Problem_Saver(plastic_problem,problem_name)

# %% [markdown]
# # Problem Solving

# %%
K = 25*2  # number of steps per load phase
Z = 2  # number of cycles
load, unload,load_2 = np.linspace(0.0, 1.0, num=K + 1), np.linspace(1.0, 0, num=K+ 1), np.linspace(-1.0, 1.0, num=K + 1)
cycle = np.concatenate((unload, load_2, unload,load_2))
cycles = np.concatenate([load,unload])

# %%
startTime = datetime.now()
Nincr = load_steps["N_incr"]

results = np.zeros((len(cycles)+1, 4))



print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

#log.set_log_level(log.LogLevel.INFO)
saver.update_and_save(0)
for (i, load) in enumerate(cycles):
    # Update Diriclet boundary condition
   
    disp.value = F_ext(load)
    # Update the right hand side reusing the initial vector

    print("Increment:", str(i+1))
    niter = 0
    print("Linear Step 1 Start")
    plastic_problem.solve_linear(bcs) #Solves for the first trial displacement
    
    
    scal = fem.assemble_vector(plastic_problem.f_trial)
    print("Linear Step 1 Done")
    if scal.array.max() >= 0:
        error_0 = scal.array.max()
        niter = 0
        nls_ttime = timedelta(0,0,0)
        linear_ttime = timedelta(0,0,0)
        print("Starting Plastic Step")
        while scal.array.max() >= 10 and niter < 20 and scal.array.max()/error_0 >.1:
           
           
            nls_time = datetime.now()
            plastic_problem.solve_nls()
            nls_ttime += datetime.now() - startTime
            linear_time = datetime.now()
            #print("Stop Plastic Step  Done")
            # print("Linear Step 2 Start")
            #f_trial = fem.assemble_scalar(fem.form(plastic_problem.res_p))
            #print(f_trial.norm())
        
            plastic_problem.solve_linear(bcs) #Solves for the actual displacement after the plastic update
            linear_ttime += datetime.now() - startTime
            plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
            plastic_problem.du.x.array[:] = 0.0
            plastic_problem.dp.x.array[:] = 0.0
            # print("Linear Step 2 Done")
            
            scal = fem.assemble_vector(plastic_problem.f_trial)
            #print(scal.array.max())
            niter +=1
        print(f"Number of iterations: {niter}")
        print(f"Nonlinear time: {nls_ttime}")
        print(f"Linear time: {linear_ttime}")
    
    
    else:
        print("Skiping Plastic Step")
        
        #vec1 = fem.assemble_vector(fem.form(plastic_problem.res_p))
        #print(plastic_problem.du.x.array)
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
    
    
    project(Stress_Point[0,0],Elastic)
    u_pointe = plastic_problem.u.eval(pointForStress,colliding_cells.array[0])[0]
    stress =  domain.comm.gather(fem.assemble_scalar(engineeringStress))[0]
    #vec2 = fem.assemble_vector(fem.form(plastic_problem.res_p))
    #print(vec1.norm())
    #print(vec2.norm())
    results[i + 1, :] = (u_pointe,stress,i+1,F_ext(load)[0])
    
    saver.update_and_save(i)
    

print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")    
saver.close()
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Increment: 1
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 2
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 3
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 4
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 5
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 6
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 7
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 8
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 9
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 10
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 11
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 12
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 13
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 14
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 15
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 16
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 17
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 18
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 19
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 20
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 21
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 22
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 23
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 24
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 25
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 26
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00
# Linear time: 0:00:00
# Increment: 27
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00
# Linear time: 0:00:00
# Increment: 28
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 1
# Nonlinear time: 0:00:00.554391
# Linear time: 0:00:00.563102
# Increment: 29
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:01.233922
# Linear time: 0:00:01.253177
# Increment: 30
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 1
# Nonlinear time: 0:00:00.690185
# Linear time: 0:00:00.699593
# Increment: 31
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:01.512859
# Linear time: 0:00:01.530972
# Increment: 32
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:01.687272
# Linear time: 0:00:01.708427
# Increment: 33
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:01.879051
# Linear time: 0:00:01.897477
# Increment: 34
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:02.037420
# Linear time: 0:00:02.055132
# Increment: 35
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:02.227065
# Linear time: 0:00:02.258400
# Increment: 36
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:02.424477
# Linear time: 0:00:02.442580
# Increment: 37
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 3
# Nonlinear time: 0:00:03.951877
# Linear time: 0:00:03.982263
# Increment: 38
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 2
# Nonlinear time: 0:00:02.869044
# Linear time: 0:00:02.890060
# Increment: 39
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 3
# Nonlinear time: 0:00:04.732332
# Linear time: 0:00:04.762281
# Increment: 40
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 4
# Nonlinear time: 0:00:07.037514
# Linear time: 0:00:07.079831
# Increment: 41
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 3
# Nonlinear time: 0:00:05.695174
# Linear time: 0:00:05.720035
# Increment: 42
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 4
# Nonlinear time: 0:00:08.074418
# Linear time: 0:00:08.106714
# Increment: 43
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 5
# Nonlinear time: 0:00:10.956107
# Linear time: 0:00:11.001464
# Increment: 44
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 5
# Nonlinear time: 0:00:11.863205
# Linear time: 0:00:11.906667
# Increment: 45
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 7
# Nonlinear time: 0:00:18.148245
# Linear time: 0:00:18.205858
# Increment: 46
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 8
# Nonlinear time: 0:00:22.658917
# Linear time: 0:00:22.724146
# Increment: 47
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 10
# Nonlinear time: 0:00:31.263149
# Linear time: 0:00:31.345691
# Increment: 48
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 15
# Nonlinear time: 0:00:53.038238
# Linear time: 0:00:53.169303
# Increment: 49
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 20
# Nonlinear time: 0:01:22.553224
# Linear time: 0:01:22.722165
# Increment: 50
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 20
# Nonlinear time: 0:01:37.091889
# Linear time: 0:01:37.294162
# Increment: 51
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 20
# Nonlinear time: 0:01:50.310238
# Linear time: 0:01:50.472645
# Increment: 52
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 20
# Nonlinear time: 0:02:03.056224
# Linear time: 0:02:03.232568
# Increment: 53
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00
# Linear time: 0:00:00
# Increment: 54
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00
# Linear time: 0:00:00
# Increment: 55
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 56
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 57
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 58
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 59
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 60
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 61
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 62
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 63
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 64
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 65
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 66
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 67
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 68
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 69
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 70
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 71
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 72
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 73
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 74
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 75
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 76
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 77
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 78
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 79
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 80
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 81
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 82
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 83
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 84
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 85
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 86
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 87
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 88
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 89
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 90
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 91
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 92
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 93
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 94
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 95
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 96
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 97
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 98
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 99
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 100
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 101
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 102
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:00:07.262226
# ------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi=500)
plt.plot(results[:, 0]/geom["longside"], results[:, 1], "-o")

#plt.plot(results[:, 0]/geom["longside"], results[:, 3], "-o")
plt.xlabel(r"Strain [$\frac{m}{m}$]")
plt.ylabel(r"Stress [MPa]")
plt.grid()
plt.show()

# %%
results[-1,1]
# Out:
# -0.3644352125738938

# %%
from matplotlib.animation import FuncAnimation, FFMpegWriter
import matplotlib.pyplot as plt
import os

plt.rcParams["animation.ffmpeg_path"] = "/usr/bin/ffmpeg"


def plot_animation(
    colors, x, y, ylabel, xlabel
):
    fig = plt.figure()
    fig.set_size_inches(7, 5)

    def animate(i):
        plt.cla()

        plt.plot(x[0:i], y[0:i], '--',linewidth=1.5)
        plt.grid(linestyle="--", linewidth=0.5, color="b")
        
        axes = fig.get_axes()[0]
        axes.set_ylabel(ylabel)
        from matplotlib.ticker import AutoMinorLocator
        
        axes.xaxis.set_minor_locator(AutoMinorLocator())
        axes.yaxis.set_minor_locator(AutoMinorLocator())
        axes.set_xlabel(xlabel)
        # ax2.plot(timeHist2[0:i], timeHist0[0:i], c=colors[0], linewidth=1.5)
        # ax2.grid(linestyle="--", linewidth=0.5, color="b")
        # ax2.set_xlabel("Time (s)")
        # ax2.set_ylabel(ylabel2)
        # from matplotlib.ticker import AutoMinorLocator

        # ax2.xaxis.set_minor_locator(AutoMinorLocator())
        # ax2.yaxis.set_minor_locator(AutoMinorLocator())

        axes.set_xlim(0, .0072)
        axes.set_ylim(0, 220)
        # ax2.set_ylim(-6.5, 6.6)

    set_fps = 24
    ani = FuncAnimation(
        fig, animate, interval=1000 / set_fps, save_count=len(x)
    )

    f = r"media/Tensile_Stress_Strain_Curve_Traction.mp4"
    if not os.path.exists('media'):
        os.makedirs('media')
    writervideo = FFMpegWriter(fps=set_fps)
    ani.save(f, writer=writervideo)

# %%
plot_animation(["blue","red","green","blue"], results[:, 0]/geom["longside"], results[:, 1],  r"Stress [Mpa]", r"Strain [$\frac{m}{m}$]")
