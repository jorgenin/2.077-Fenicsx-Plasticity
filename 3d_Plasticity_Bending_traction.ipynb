# %% [markdown]
# # Built In Beam in Bending

# %%
import numpy as np

import dolfinx

from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log,default_scalar_type
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem,LinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import XDMFFile, VTXWriter
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional , gt, dx, inner, derivative, dot, ln, split,TestFunction,indices,as_tensor)
from basix.ufl import element, mixed_element, quadrature_element
from datetime import datetime, timedelta
from dolfinx.plot import vtk_mesh
from dolfinx.fem.petsc import  assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc,create_matrix, create_vector
import basix
import pyvista

pyvista.set_jupyter_backend('client')

from ElasticPlasticity.Plastic_material import Plastic_Material
from ElasticPlasticity.Plastic_Visibility import Problem_Saver
from ElasticPlasticity.Plasticity_Funcs import *
from ElasticPlasticity.Plasticity_Problem import Plastic_Problem_Def

# %%
problem_name = "Plastic Bending Traction"
# Geometric parameters
geom = {"longside" : 100.0,     # mm
        "side" : 10.0,      # mm
        "num_elements" : 5,    # size of a cell
        }


# Mechanicals parameters
mech = {"E" : 300e3,    # MPa
        "nu" : 0.3,     #       
        "sig0" : 180.0,  # MPa
        "H" : 20.0, # MPa
        "r" : 1.0,
        "Y_s" :300.0,#mpa
        "C" : 60.0e3,
        "gamma":10.0
        }


# Study parameters
stud = {"deg_u" : 1,    # Interpolation of u
        "deg_strain_quad" : 2,  # Interpolation of sig, eps, p
        }

load_steps  = {
        "N_incr" : 60,  # Number of load steps
        "max_disp" : 3.0 # Maximal displacemen
        }

# %% [markdown]
# # Domain and Boundary Definition

# %%
domain = mesh.create_box(MPI.COMM_WORLD,[[0.0,0.0,0.0],[geom["longside"],geom["side"],geom["side"]]],[geom["num_elements"]*10,geom["num_elements"],geom["num_elements"]])


def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], geom["longside"])
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], geom["side"])
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], geom["side"])

boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

facet_indices, facet_markers = [], []
fdim = domain.topology.dim - 1
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator)
    facet_indices.append(facets)
    facet_markers.append(np.full_like(facets, marker))

facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
mat = Plastic_Material(domain = domain,**mech)
plastic_problem = Plastic_Problem_Def(domain,mat,facet_tags=facet_tag,**stud)

# %% [markdown]
# # Boundary Conditions

# %%
left_facets = facet_tag.find(1)
right_facets = facet_tag.find(2)


top_facets = facet_tag.find(3)
side_facets = facet_tag.find(5)
fdim = domain.topology.dim - 1
domain.topology.create_connectivity(fdim, domain.topology.dim)
disp = Constant(domain,0.0)

left_dofs_x = fem.locate_dofs_topological(plastic_problem.V, fdim, left_facets)

right_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(1),fdim, right_facets)

sym_bottom = fem.dirichletbc(np.array((0.0,0.0,0.0),dtype=default_scalar_type), left_dofs_x, plastic_problem.V)
sym_left = fem.dirichletbc(disp, right_dofs_x, plastic_problem.V.sub(1))



bcs = [sym_bottom]

#bcs = [sym_bottom, sym_left]

disp = Constant(domain,(0.0,0.0,0.0))


def F_ext(t):
    arr = np.zeros((3,))
    arr[1] = t*8 #mpa
    return arr

# %%
plastic_problem._init_linear_problem([(-disp,plastic_problem.ds(2))])

# %% [markdown]
# # Data for Plotting

# %%
E_n = eps(plastic_problem.u)
E_p = plastic_problem.E_p

Stress_Point = mat.sigma(E_n - E_p)
area= Constant(domain,(geom["side"]*geom["side"]))
Elastic = Function(plastic_problem.V_scal)

project(Stress_Point[0,1],Elastic)
engineeringStress= fem.form(Elastic/area*plastic_problem.ds(2)) #P22/area*ds


pointForStress = [geom["longside"],5,5]

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, np.array(pointForStress))
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates,  np.array(pointForStress))

# %%
saver = Problem_Saver(plastic_problem,problem_name)

# %% [markdown]
# # Problem Solving

# %%
K = 25*2  # number of steps per load phase
Z = 2  # number of cycles
load, unload,load_2 = np.linspace(0.0, 1.0, num=K + 1), np.linspace(1.0, 0, num=K+ 1), np.linspace(-1.0, 1.0, num=K + 1)
cycle = np.concatenate((unload, load_2, unload,load_2))
cycles = np.concatenate([load]+[unload])
loads = cycles

# %%
startTime = datetime.now()
Nincr = load_steps["N_incr"]

results = np.zeros((len(cycles)+1, 4))
#F = np.vectorize(F_ext)


print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

#log.set_log_level(log.LogLevel.INFO)
saver.update_and_save(0)
for (i, load) in enumerate(loads):
    # Update Diriclet boundary condition
   
    disp.value = F_ext(load)
    # Update the right hand side reusing the initial vector

    print("Increment:", str(i+1))
    niter = 0
    print("Linear Step 1 Start")
    plastic_problem.solve_linear(bcs) #Solves for the first trial displacement
    
    
    scal = fem.assemble_vector(plastic_problem.f_trial)
    print("Linear Step 1 Done")
    if scal.array.max() >= 0:
        error_0 = scal.array.max()
        niter = 0
        nls_ttime = timedelta(0,0,0)
        linear_ttime = timedelta(0,0,0)
        print("Starting Plastic Step")
        #while scal.array.max() >= 10 and niter < 10 and scal.array.max()/error_0 >.3:
           
            
        nls_time = datetime.now()
        plastic_problem.solve_nls()
        nls_ttime += datetime.now() - startTime
        linear_time = datetime.now()
        #print("Stop Plastic Step  Done")
        # print("Linear Step 2 Start")
        #f_trial = fem.assemble_scalar(fem.form(plastic_problem.res_p))
        #print(f_trial.norm())
    
        plastic_problem.solve_linear(bcs) #Solves for the actual displacement after the plastic update
        linear_ttime += datetime.now() - startTime
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
            # print("Linear Step 2 Done")
            
            #scal = fem.assemble_vector(plastic_problem.f_trial)
            #print(scal.array.max())
            #niter +=1
        print(f"Number of iterations: {niter}")
        print(f"Nonlinear time: {nls_ttime}")
        print(f"Linear time: {linear_ttime}")
    
    
    else:
        print("Skiping Plastic Step")
        
        #vec1 = fem.assemble_vector(fem.form(plastic_problem.res_p))
        #print(plastic_problem.du.x.array)
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
    
    
    project(Stress_Point[0,1],Elastic)
    u_pointe = plastic_problem.u.eval(pointForStress,colliding_cells.array[0])[1]
    stress =  domain.comm.gather(fem.assemble_scalar(engineeringStress))[0]
    #vec2 = fem.assemble_vector(fem.form(plastic_problem.res_p))
    #print(vec1.norm())
    #print(vec2.norm())
    results[i + 1, :] = (u_pointe,stress,i+1,F_ext(load)[1])
    
    saver.update_and_save(i)
    

print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")    
saver.close()
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Increment: 1
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 2
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 3
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 4
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 5
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 6
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 7
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 8
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 9
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 10
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 11
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 12
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 13
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 14
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 15
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 16
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 17
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 18
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 19
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 20
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 21
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 22
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 23
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 24
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.545125
# Linear time: 0:00:02.618439
# Increment: 25
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.761254
# Linear time: 0:00:02.834010
# Increment: 26
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.971381
# Linear time: 0:00:03.051041
# Increment: 27
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.196002
# Linear time: 0:00:03.267919
# Increment: 28
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.420479
# Linear time: 0:00:03.494230
# Increment: 29
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.649863
# Linear time: 0:00:03.722402
# Increment: 30
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.873821
# Linear time: 0:00:03.946080
# Increment: 31
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.096124
# Linear time: 0:00:04.180845
# Increment: 32
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.335466
# Linear time: 0:00:04.408147
# Increment: 33
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.559047
# Linear time: 0:00:04.631957
# Increment: 34
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.782341
# Linear time: 0:00:04.854324
# Increment: 35
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.005003
# Linear time: 0:00:05.076963
# Increment: 36
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.230424
# Linear time: 0:00:05.303156
# Increment: 37
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.457868
# Linear time: 0:00:05.529426
# Increment: 38
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.678978
# Linear time: 0:00:05.753003
# Increment: 39
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.907587
# Linear time: 0:00:05.980146
# Increment: 40
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.133493
# Linear time: 0:00:06.208696
# Increment: 41
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.370011
# Linear time: 0:00:06.453899
# Increment: 42
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.611510
# Linear time: 0:00:06.687776
# Increment: 43
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.854431
# Linear time: 0:00:06.928320
# Increment: 44
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.106443
# Linear time: 0:00:07.182440
# Increment: 45
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.343416
# Linear time: 0:00:07.425891
# Increment: 46
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.615191
# Linear time: 0:00:07.694831
# Increment: 47
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.867971
# Linear time: 0:00:07.943536
# Increment: 48
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.113149
# Linear time: 0:00:08.205540
# Increment: 49
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.372309
# Linear time: 0:00:08.449828
# Increment: 50
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.630368
# Linear time: 0:00:08.709412
# Increment: 51
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.918750
# Linear time: 0:00:09.005938
# Increment: 52
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.186138
# Linear time: 0:00:09.263057
# Increment: 53
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.421265
# Linear time: 0:00:09.493233
# Increment: 54
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.645501
# Linear time: 0:00:09.719697
# Increment: 55
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.878425
# Linear time: 0:00:09.966414
# Increment: 56
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.125471
# Linear time: 0:00:10.199342
# Increment: 57
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.358272
# Linear time: 0:00:10.435019
# Increment: 58
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.601659
# Linear time: 0:00:10.680844
# Increment: 59
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.838666
# Linear time: 0:00:10.921900
# Increment: 60
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.164039
# Linear time: 0:00:11.239509
# Increment: 61
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.407538
# Linear time: 0:00:11.485630
# Increment: 62
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.686408
# Linear time: 0:00:11.773815
# Increment: 63
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.963076
# Linear time: 0:00:12.039786
# Increment: 64
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.208816
# Linear time: 0:00:12.291230
# Increment: 65
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.456175
# Linear time: 0:00:12.533027
# Increment: 66
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.784926
# Linear time: 0:00:12.873919
# Increment: 67
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.074711
# Linear time: 0:00:13.183934
# Increment: 68
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.360493
# Linear time: 0:00:13.444635
# Increment: 69
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.617834
# Linear time: 0:00:13.704639
# Increment: 70
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.862760
# Linear time: 0:00:13.945493
# Increment: 71
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.109546
# Linear time: 0:00:14.190259
# Increment: 72
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.353760
# Linear time: 0:00:14.439659
# Increment: 73
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.600280
# Linear time: 0:00:14.683498
# Increment: 74
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.880190
# Linear time: 0:00:14.977475
# Increment: 75
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.143597
# Linear time: 0:00:15.221137
# Increment: 76
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.381834
# Linear time: 0:00:15.466985
# Increment: 77
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.632651
# Linear time: 0:00:15.718530
# Increment: 78
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.870656
# Linear time: 0:00:15.944230
# Increment: 79
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.090707
# Linear time: 0:00:16.165960
# Increment: 80
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.313035
# Linear time: 0:00:16.386967
# Increment: 81
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.533498
# Linear time: 0:00:16.614743
# Increment: 82
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.767960
# Linear time: 0:00:16.844017
# Increment: 83
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.997505
# Linear time: 0:00:17.074719
# Increment: 84
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.252989
# Linear time: 0:00:17.330836
# Increment: 85
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.480323
# Linear time: 0:00:17.561348
# Increment: 86
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.715125
# Linear time: 0:00:17.807100
# Increment: 87
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.969238
# Linear time: 0:00:18.049499
# Increment: 88
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.230934
# Linear time: 0:00:18.313263
# Increment: 89
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.462703
# Linear time: 0:00:18.539889
# Increment: 90
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.681018
# Linear time: 0:00:18.753945
# Increment: 91
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.894202
# Linear time: 0:00:18.969114
# Increment: 92
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.117870
# Linear time: 0:00:19.200419
# Increment: 93
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.355382
# Linear time: 0:00:19.432584
# Increment: 94
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.583208
# Linear time: 0:00:19.660677
# Increment: 95
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.812605
# Linear time: 0:00:19.891436
# Increment: 96
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.044027
# Linear time: 0:00:20.120494
# Increment: 97
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.267185
# Linear time: 0:00:20.343535
# Increment: 98
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.487114
# Linear time: 0:00:20.564695
# Increment: 99
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.731416
# Linear time: 0:00:20.806648
# Increment: 100
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.970408
# Linear time: 0:00:21.048096
# Increment: 101
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.207116
# Linear time: 0:00:21.284386
# Increment: 102
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.485141
# Linear time: 0:00:21.559594
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:00:21.574635
# ------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi=500)
plt.plot(results[:, 1], results[:, 0], "-o")

#plt.plot(results[:, 0]/geom["longside"], results[:, 3], "-o")
plt.xlabel(r"Stress [Mpa]")
plt.ylabel(r"Deflection [mm]")
plt.grid()
plt.show()
