# %% [markdown]
# # Built In Beam in Bending

# %%
import numpy as np

import dolfinx

from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log,default_scalar_type
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem,LinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import XDMFFile, VTXWriter
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional , gt, dx, inner, derivative, dot, ln, split,TestFunction,indices,as_tensor)
from basix.ufl import element, mixed_element, quadrature_element
from datetime import datetime, timedelta
from dolfinx.plot import vtk_mesh
from dolfinx.fem.petsc import  assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc,create_matrix, create_vector
import basix
import pyvista
pyvista.set_jupyter_backend('client')

from ElasticPlasticity.Plastic_material import Plastic_Material
from ElasticPlasticity.Plastic_Visibility import Problem_Saver
from ElasticPlasticity.Plasticity_Funcs import *
from ElasticPlasticity.Plasticity_Problem import Plastic_Problem_Def

# %%
problem_name = "Plastic Bending Traction"
# Geometric parameters
geom = {"longside" : 100.0,     # mm
        "side" : 10.0,      # mm
        "num_elements" : 5,    # size of a cell
        }


# Mechanicals parameters
mech = {"E" : 300e3,    # MPa
        "nu" : 0.3,     #       
        "sig0" : 180.0,  # MPa
        "H" : 20.0, # MPa
        "r" : 1.0,
        "Y_s" :300.0,#mpa
        "C" : 60.0e3,
        "gamma":10.0
        
        }


# Study parameters
stud = {"deg_u" : 1,    # Interpolation of u
        "deg_stress" : 2,  # Interpolation of sig, eps, p
        }

load_steps  = {
        "N_incr" : 60,  # Number of load steps
        "max_disp" : 3.0 # Maximal displacemen
        }

# %% [markdown]
# # Domain and Boundary Definition

# %%
domain = mesh.create_box(MPI.COMM_WORLD,[[0.0,0.0,0.0],[geom["longside"],geom["side"],geom["side"]]],[geom["num_elements"]*10,geom["num_elements"],geom["num_elements"]])


def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], geom["longside"])
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], geom["side"])
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], geom["side"])

boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

facet_indices, facet_markers = [], []
fdim = domain.topology.dim - 1
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator)
    facet_indices.append(facets)
    facet_markers.append(np.full_like(facets, marker))

facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
mat = Plastic_Material(domain = domain,**mech)
plastic_problem = Plastic_Problem_Def(domain,mat,facet_tags=facet_tag,**stud)

# %% [markdown]
# # Boundary Conditions

# %%
left_facets = facet_tag.find(1)

right_facets = facet_tag.find(2)


top_facets = facet_tag.find(3)
side_facets = facet_tag.find(5)
fdim = domain.topology.dim - 1
domain.topology.create_connectivity(fdim, domain.topology.dim)
disp = Constant(domain,0.0)

left_dofs_x = fem.locate_dofs_topological(plastic_problem.V, fdim, left_facets)

right_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(1),fdim, right_facets)

sym_bottom = fem.dirichletbc(np.array((0.0,0.0,0.0),dtype=default_scalar_type), left_dofs_x, plastic_problem.V)
sym_left = fem.dirichletbc(disp, right_dofs_x, plastic_problem.V.sub(1))



bcs = [sym_bottom]

#bcs = [sym_bottom, sym_left]

disp = Constant(domain,(0.0,0.0,0.0))


def F_ext(t):
    arr = np.zeros((3,))
    arr[1] = t*8
    return arr

# %%
plastic_problem._init_linear_problem([(-disp,plastic_problem.ds(2))])

# %% [markdown]
# # Data for Plotting

# %%
E_n = eps(plastic_problem.u)
E_p = plastic_problem.E_p

Stress_Point = mat.sigma(E_n - E_p)
area= Constant(domain,(geom["side"]*geom["side"]))
Elastic = Function(plastic_problem.V_scal)

project(Stress_Point[0,1],Elastic)
engineeringStress= fem.form(Elastic/area*plastic_problem.ds(2)) #P22/area*ds


pointForStress = [geom["longside"],5,5]

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, np.array(pointForStress))
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates,  np.array(pointForStress))

# %%
saver = Problem_Saver(plastic_problem,problem_name)

# %% [markdown]
# # Problem Solving

# %%
K = 25*2  # number of steps per load phase
Z = 2  # number of cycles
load, unload,load_2 = np.linspace(0.0, 1.0, num=K + 1), np.linspace(1.0, 0, num=K+ 1), np.linspace(-1.0, 1.0, num=K + 1)
cycle = np.concatenate((unload, load_2, unload,load_2))
cycles = np.concatenate([load]+[unload])
loads = cycles

# %%
startTime = datetime.now()
Nincr = load_steps["N_incr"]

results = np.zeros((len(cycles)+1, 4))
#F = np.vectorize(F_ext)


print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

#log.set_log_level(log.LogLevel.INFO)
saver.update_and_save(0)
for (i, load) in enumerate(loads):
    # Update Diriclet boundary condition
   
    disp.value = F_ext(load)
    # Update the right hand side reusing the initial vector

    print("Increment:", str(i+1))
    niter = 0
    print("Linear Step 1 Start")
    plastic_problem.solve_linear(bcs) #Solves for the first trial displacement
    
    
    scal = fem.assemble_vector(plastic_problem.f_trial)
    print("Linear Step 1 Done")
    if scal.array.max() >= 0:
        error_0 = scal.array.max()
        niter = 0
        nls_ttime = timedelta(0,0,0)
        linear_ttime = timedelta(0,0,0)
        print("Starting Plastic Step")
        #while scal.array.max() >= 10 and niter < 10 and scal.array.max()/error_0 >.3:
           
            
        nls_time = datetime.now()
        plastic_problem.solve_nls()
        nls_ttime += datetime.now() - startTime
        linear_time = datetime.now()
        #print("Stop Plastic Step  Done")
        # print("Linear Step 2 Start")
        #f_trial = fem.assemble_scalar(fem.form(plastic_problem.res_p))
        #print(f_trial.norm())
    
        plastic_problem.solve_linear(bcs) #Solves for the actual displacement after the plastic update
        linear_ttime += datetime.now() - startTime
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
            # print("Linear Step 2 Done")
            
            #scal = fem.assemble_vector(plastic_problem.f_trial)
            #print(scal.array.max())
            #niter +=1
        print(f"Number of iterations: {niter}")
        print(f"Nonlinear time: {nls_ttime}")
        print(f"Linear time: {linear_ttime}")
    
    
    else:
        print("Skiping Plastic Step")
        
        #vec1 = fem.assemble_vector(fem.form(plastic_problem.res_p))
        #print(plastic_problem.du.x.array)
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
    
    
    project(Stress_Point[0,1],Elastic)
    u_pointe = plastic_problem.u.eval(pointForStress,colliding_cells.array[0])[1]
    stress =  domain.comm.gather(fem.assemble_scalar(engineeringStress))[0]
    #vec2 = fem.assemble_vector(fem.form(plastic_problem.res_p))
    #print(vec1.norm())
    #print(vec2.norm())
    results[i + 1, :] = (u_pointe,stress,i+1,F_ext(load)[1])
    
    saver.update_and_save(i)
    

print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")    
saver.close()
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Increment: 1
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 2
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 3
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 4
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 5
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 6
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 7
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 8
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 9
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 10
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 11
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 12
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 13
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 14
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 15
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 16
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 17
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 18
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 19
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 20
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 21
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 22
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 23
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 24
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.183410
# Linear time: 0:00:02.253313
# Increment: 25
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.395069
# Linear time: 0:00:02.467504
# Increment: 26
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.609595
# Linear time: 0:00:02.679354
# Increment: 27
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.815757
# Linear time: 0:00:02.886027
# Increment: 28
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.042930
# Linear time: 0:00:03.110932
# Increment: 29
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.261296
# Linear time: 0:00:03.330476
# Increment: 30
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.486646
# Linear time: 0:00:03.557059
# Increment: 31
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.709763
# Linear time: 0:00:03.780888
# Increment: 32
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.937068
# Linear time: 0:00:04.006022
# Increment: 33
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.159190
# Linear time: 0:00:04.227824
# Increment: 34
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.380677
# Linear time: 0:00:04.450528
# Increment: 35
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.607234
# Linear time: 0:00:04.676805
# Increment: 36
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.839873
# Linear time: 0:00:04.910515
# Increment: 37
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.072542
# Linear time: 0:00:05.141632
# Increment: 38
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.298843
# Linear time: 0:00:05.369033
# Increment: 39
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.524532
# Linear time: 0:00:05.595284
# Increment: 40
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.749350
# Linear time: 0:00:05.820652
# Increment: 41
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.981951
# Linear time: 0:00:06.056102
# Increment: 42
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.222565
# Linear time: 0:00:06.293546
# Increment: 43
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.458535
# Linear time: 0:00:06.530015
# Increment: 44
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.702139
# Linear time: 0:00:06.772121
# Increment: 45
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.938397
# Linear time: 0:00:07.009139
# Increment: 46
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.173361
# Linear time: 0:00:07.246685
# Increment: 47
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.423883
# Linear time: 0:00:07.497241
# Increment: 48
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.663171
# Linear time: 0:00:07.734753
# Increment: 49
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.898397
# Linear time: 0:00:07.971760
# Increment: 50
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.132910
# Linear time: 0:00:08.205410
# Increment: 51
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.359720
# Linear time: 0:00:08.431054
# Increment: 52
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.586233
# Linear time: 0:00:08.655379
# Increment: 53
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.814776
# Linear time: 0:00:08.886474
# Increment: 54
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.041692
# Linear time: 0:00:09.112325
# Increment: 55
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.270770
# Linear time: 0:00:09.341402
# Increment: 56
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.495767
# Linear time: 0:00:09.566611
# Increment: 57
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.717336
# Linear time: 0:00:09.786492
# Increment: 58
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.939390
# Linear time: 0:00:10.010081
# Increment: 59
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.162851
# Linear time: 0:00:10.233809
# Increment: 60
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.389122
# Linear time: 0:00:10.457517
# Increment: 61
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.621546
# Linear time: 0:00:10.691245
# Increment: 62
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.839453
# Linear time: 0:00:10.912236
# Increment: 63
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.075358
# Linear time: 0:00:11.147156
# Increment: 64
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.302984
# Linear time: 0:00:11.373984
# Increment: 65
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.528726
# Linear time: 0:00:11.599501
# Increment: 66
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.764228
# Linear time: 0:00:11.838553
# Increment: 67
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.999247
# Linear time: 0:00:12.076184
# Increment: 68
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.215014
# Linear time: 0:00:12.286346
# Increment: 69
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.430587
# Linear time: 0:00:12.505220
# Increment: 70
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.646686
# Linear time: 0:00:12.718920
# Increment: 71
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.865685
# Linear time: 0:00:12.938281
# Increment: 72
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.073161
# Linear time: 0:00:13.141852
# Increment: 73
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.276691
# Linear time: 0:00:13.347185
# Increment: 74
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.483879
# Linear time: 0:00:13.552083
# Increment: 75
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.686975
# Linear time: 0:00:13.757584
# Increment: 76
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.899031
# Linear time: 0:00:13.969131
# Increment: 77
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.105213
# Linear time: 0:00:14.172762
# Increment: 78
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.305312
# Linear time: 0:00:14.373342
# Increment: 79
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.507317
# Linear time: 0:00:14.577118
# Increment: 80
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.717709
# Linear time: 0:00:14.787636
# Increment: 81
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.923382
# Linear time: 0:00:14.992944
# Increment: 82
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.127048
# Linear time: 0:00:15.196890
# Increment: 83
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.353992
# Linear time: 0:00:15.425424
# Increment: 84
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.567338
# Linear time: 0:00:15.638625
# Increment: 85
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.778551
# Linear time: 0:00:15.848450
# Increment: 86
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:15.989698
# Linear time: 0:00:16.061078
# Increment: 87
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.198117
# Linear time: 0:00:16.268507
# Increment: 88
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.401543
# Linear time: 0:00:16.469569
# Increment: 89
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.602783
# Linear time: 0:00:16.670893
# Increment: 90
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:16.805635
# Linear time: 0:00:16.876971
# Increment: 91
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.018920
# Linear time: 0:00:17.088433
# Increment: 92
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.226380
# Linear time: 0:00:17.296434
# Increment: 93
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.440992
# Linear time: 0:00:17.510900
# Increment: 94
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.650246
# Linear time: 0:00:17.720871
# Increment: 95
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.860037
# Linear time: 0:00:17.931834
# Increment: 96
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.071514
# Linear time: 0:00:18.143743
# Increment: 97
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.283938
# Linear time: 0:00:18.354113
# Increment: 98
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.497869
# Linear time: 0:00:18.570565
# Increment: 99
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.725001
# Linear time: 0:00:18.794186
# Increment: 100
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.945487
# Linear time: 0:00:19.015815
# Increment: 101
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.162877
# Linear time: 0:00:19.232076
# Increment: 102
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.390077
# Linear time: 0:00:19.459999
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:00:19.476014
# ------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi=500)
plt.plot(results[:, 1], results[:, 0], "-o")

#plt.plot(results[:, 0]/geom["longside"], results[:, 3], "-o")
plt.xlabel(r"Stress [Mpa]")
plt.ylabel(r"Deflection [mm]")
plt.grid()
plt.show()
