# %%
import numpy as np

import dolfinx

from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log,default_scalar_type
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem,LinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import XDMFFile, VTXWriter
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional , gt, dx, inner, derivative, dot, ln, split,TestFunction,indices,as_tensor)
from basix.ufl import element, mixed_element, quadrature_element
from datetime import datetime, timedelta
from dolfinx.plot import vtk_mesh
from dolfinx.fem.petsc import  assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc,create_matrix, create_vector
import basix
import pyvista
pyvista.set_jupyter_backend('client')

from ElasticPlasticity.Plastic_material import Plastic_Material
from ElasticPlasticity.Plastic_Visibility import Problem_Saver
from ElasticPlasticity.Plasticity_Funcs import *
from ElasticPlasticity.Plasticity_Problem import Plastic_Problem_Def

# %%
problem_name = "Plastic Tensile Test"
# Geometric parameters
geom = {"longside" : 100.0,     # mm
        "side" : 10.0,      # mm
        "num_elements" : 3,    # size of a cell
        }


# Mechanicals parameters
mech = {"E" : 200e3,    # MPa
        "nu" : 0.3,     #       
        "sig0" : 100.0,  # MPa
        "H" : 1250.0, # MPa
        "r" : 1.0,
        "Y_s" :300.0,#mpa
        "C" : 40.0e3,
        "gamma":400.0
        
        }


# Study parameters
stud = {"deg_u" : 1,    # Interpolation of u
        "deg_strain_quad" : 2,  # Interpolation of sig, eps, p
        }

load_steps  = {
        "N_incr" : 60,  # Number of load steps
        "max_disp" : 1 # Maximal displacemen
        }

# %% [markdown]
# # Domain and Boundary Definition

# %%
domain = mesh.create_box(MPI.COMM_WORLD,[[0.0,0.0,0.0],[geom["longside"],geom["side"],geom["side"]]],[geom["num_elements"]*10,geom["num_elements"],geom["num_elements"]])


def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], geom["longside"])
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], geom["side"])
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], geom["side"])

boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

facet_indices, facet_markers = [], []
fdim = domain.topology.dim - 1
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator)
    facet_indices.append(facets)
    facet_markers.append(np.full_like(facets, marker))

facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
mat = Plastic_Material(domain = domain,**mech)
plastic_problem = Plastic_Problem_Def(domain,mat,facet_tags=facet_tag,**stud)

# %% [markdown]
# # Boundary Conditions

# %%
from json import load


left_facets = facet_tag.find(1)

right_facets = facet_tag.find(2)


top_facets = facet_tag.find(3)
side_facets = facet_tag.find(5)
fdim = domain.topology.dim - 1
domain.topology.create_connectivity(fdim, domain.topology.dim)
disp = Constant(domain,0.0)

left_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(0), fdim, left_facets)
top_dof_y = fem.locate_dofs_topological(plastic_problem.V.sub(1), fdim, top_facets)
top_dof_z = fem.locate_dofs_topological(plastic_problem.V.sub(2), fdim, side_facets)
right_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(0),fdim, right_facets)

sym_bottom = fem.dirichletbc(0.0, left_dofs_x, plastic_problem.V.sub(0))
sym_left = fem.dirichletbc(disp, right_dofs_x, plastic_problem.V.sub(0))

sym_top = fem.dirichletbc(0.0, top_dof_z, plastic_problem.V.sub(1))
sym_side = fem.dirichletbc(0.0, top_dof_y, plastic_problem.V.sub(2))

bcs = [sym_bottom,sym_top,sym_side,sym_left]

#bcs = [sym_bottom, sym_left]

#disp = Constant(domain,(0.0,0.0,0.0))


def F_ext(t):
    arr = np.zeros((3,))
    arr[0] = t*200.0
    return t*load_steps["max_disp"]

# %%
#plastic_problem._init_linear_problem([(-disp,plastic_problem.ds(2))])

# %% [markdown]
# # Data for Plotting

# %%
E_n = eps(plastic_problem.u)
E_p = plastic_problem.E_p

Stress_Point = mat.sigma(E_n - E_p)
area= Constant(domain,(geom["side"]*geom["side"]))
Elastic = Function(plastic_problem.V_scal)

project(Stress_Point[0,0],Elastic)
engineeringStress= fem.form(Elastic/area*plastic_problem.ds(2)) #P22/area*ds


pointForStress = [geom["longside"],5,5]

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, np.array(pointForStress))
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates,  np.array(pointForStress))

# %%
saver = Problem_Saver(plastic_problem,problem_name)

# %% [markdown]
# # Problem Solving

# %%
K = 25*2  # number of steps per load phase
Z = 2  # number of cycles
load, unload,load_2 = np.linspace(0.0, 1.0, num=K + 1), np.linspace(1.0, -1.0, num=K+ 1), np.linspace(-1.0, 1.0, num=K + 1)
cycle = np.concatenate((unload, load_2, unload,load_2))
cycles = np.concatenate([load]+[cycle] * Z)

# %%
startTime = datetime.now()
Nincr = load_steps["N_incr"]

results = np.zeros((len(cycles)+1, 4))

loads = cycles*load_steps["max_disp"]

print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

#log.set_log_level(log.LogLevel.INFO)
saver.update_and_save(0)
for (i, load) in enumerate(loads):
    # Update Diriclet boundary condition
   
    disp.value = load
    # Update the right hand side reusing the initial vector

    print("Increment:", str(i+1))
    niter = 0
    print("Linear Step 1 Start")
    plastic_problem.solve_linear(bcs) #Solves for the first trial displacement
    
    
    scal = fem.assemble_vector(plastic_problem.f_trial)
    print("Linear Step 1 Done")
    if scal.array.max() >= 0:
        error_0 = scal.array.max()
        niter = 0
        nls_ttime = timedelta(0,0,0)
        linear_ttime = timedelta(0,0,0)
        print("Starting Plastic Step")
        #while scal.array.max() >= 10 and niter < 20 and scal.array.max()/error_0 >.1:
           
           
        nls_time = datetime.now()
        plastic_problem.solve_nls()
        nls_ttime += datetime.now() - startTime
        linear_time = datetime.now()
        #print("Stop Plastic Step  Done")
        # print("Linear Step 2 Start")
        #f_trial = fem.assemble_scalar(fem.form(plastic_problem.res_p))
        #print(f_trial.norm())
    
        plastic_problem.solve_linear(bcs) #Solves for the actual displacement after the plastic update
        linear_ttime += datetime.now() - startTime
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
        # print("Linear Step 2 Done")
        
        #scal = fem.assemble_vector(plastic_problem.f_trial)
        #print(scal.array.max())
        #niter +=1
        print(f"Number of iterations: {niter}")
        print(f"Nonlinear time: {nls_ttime}")
        print(f"Linear time: {linear_ttime}")
    
    
    else:
        print("Skiping Plastic Step")
        
        #vec1 = fem.assemble_vector(fem.form(plastic_problem.res_p))
        #print(plastic_problem.du.x.array)
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
    
    
    project(Stress_Point[0,0],Elastic)
    u_pointe = plastic_problem.u.eval(pointForStress,colliding_cells.array[0])[0]
    stress =  domain.comm.gather(fem.assemble_scalar(engineeringStress))[0]
    #vec2 = fem.assemble_vector(fem.form(plastic_problem.res_p))
    #print(vec1.norm())
    #print(vec2.norm())
    results[i + 1, :] = (u_pointe,stress,i+1,load)
    
    saver.update_and_save(i)
    

print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")    
saver.close()
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Increment: 1
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 2
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 3
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 4
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.090889
# Linear time: 0:00:00.098973
# Increment: 5
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.137806
# Linear time: 0:00:00.146802
# Increment: 6
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.182378
# Linear time: 0:00:00.190231
# Increment: 7
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.223934
# Linear time: 0:00:00.231850
# Increment: 8
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.265236
# Linear time: 0:00:00.273067
# Increment: 9
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.306397
# Linear time: 0:00:00.314115
# Increment: 10
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.347896
# Linear time: 0:00:00.355970
# Increment: 11
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.390258
# Linear time: 0:00:00.398278
# Increment: 12
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.432738
# Linear time: 0:00:00.441320
# Increment: 13
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.477040
# Linear time: 0:00:00.484813
# Increment: 14
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.518126
# Linear time: 0:00:00.526239
# Increment: 15
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.560931
# Linear time: 0:00:00.568747
# Increment: 16
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.603957
# Linear time: 0:00:00.612012
# Increment: 17
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.650007
# Linear time: 0:00:00.658235
# Increment: 18
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.695581
# Linear time: 0:00:00.703629
# Increment: 19
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.739586
# Linear time: 0:00:00.747799
# Increment: 20
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.784130
# Linear time: 0:00:00.792278
# Increment: 21
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.827072
# Linear time: 0:00:00.835156
# Increment: 22
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.871104
# Linear time: 0:00:00.879276
# Increment: 23
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.914461
# Linear time: 0:00:00.922616
# Increment: 24
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.956108
# Linear time: 0:00:00.964305
# Increment: 25
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:00.999346
# Linear time: 0:00:01.007552
# Increment: 26
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.041756
# Linear time: 0:00:01.049865
# Increment: 27
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.084590
# Linear time: 0:00:01.092958
# Increment: 28
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.126939
# Linear time: 0:00:01.135100
# Increment: 29
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.168951
# Linear time: 0:00:01.177093
# Increment: 30
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.210750
# Linear time: 0:00:01.218806
# Increment: 31
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.252865
# Linear time: 0:00:01.260811
# Increment: 32
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.294098
# Linear time: 0:00:01.302221
# Increment: 33
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.337725
# Linear time: 0:00:01.345733
# Increment: 34
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.381830
# Linear time: 0:00:01.390429
# Increment: 35
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.424617
# Linear time: 0:00:01.432837
# Increment: 36
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.466704
# Linear time: 0:00:01.474573
# Increment: 37
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.508425
# Linear time: 0:00:01.516342
# Increment: 38
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.550997
# Linear time: 0:00:01.559077
# Increment: 39
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.593415
# Linear time: 0:00:01.601743
# Increment: 40
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.637534
# Linear time: 0:00:01.645480
# Increment: 41
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.679550
# Linear time: 0:00:01.687327
# Increment: 42
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.720184
# Linear time: 0:00:01.727915
# Increment: 43
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.761689
# Linear time: 0:00:01.769502
# Increment: 44
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.803298
# Linear time: 0:00:01.811102
# Increment: 45
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.843815
# Linear time: 0:00:01.851768
# Increment: 46
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.884444
# Linear time: 0:00:01.892590
# Increment: 47
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.926487
# Linear time: 0:00:01.934445
# Increment: 48
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:01.969689
# Linear time: 0:00:01.977919
# Increment: 49
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.013946
# Linear time: 0:00:02.022066
# Increment: 50
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.061859
# Linear time: 0:00:02.069995
# Increment: 51
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.105600
# Linear time: 0:00:02.113716
# Increment: 52
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.148457
# Linear time: 0:00:02.157004
# Increment: 53
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 54
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 55
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.226194
# Linear time: 0:00:02.235396
# Increment: 56
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.281922
# Linear time: 0:00:02.290138
# Increment: 57
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.326375
# Linear time: 0:00:02.334520
# Increment: 58
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.382488
# Linear time: 0:00:02.394115
# Increment: 59
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.440284
# Linear time: 0:00:02.448693
# Increment: 60
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.490397
# Linear time: 0:00:02.498958
# Increment: 61
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.537959
# Linear time: 0:00:02.545987
# Increment: 62
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.586851
# Linear time: 0:00:02.595606
# Increment: 63
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.635434
# Linear time: 0:00:02.643442
# Increment: 64
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.684829
# Linear time: 0:00:02.693067
# Increment: 65
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.733291
# Linear time: 0:00:02.741368
# Increment: 66
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.781149
# Linear time: 0:00:02.789651
# Increment: 67
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.831411
# Linear time: 0:00:02.840130
# Increment: 68
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.879367
# Linear time: 0:00:02.887713
# Increment: 69
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.926000
# Linear time: 0:00:02.934737
# Increment: 70
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:02.971551
# Linear time: 0:00:02.979680
# Increment: 71
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.017940
# Linear time: 0:00:03.026533
# Increment: 72
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.066496
# Linear time: 0:00:03.076362
# Increment: 73
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.117442
# Linear time: 0:00:03.125670
# Increment: 74
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.166141
# Linear time: 0:00:03.174566
# Increment: 75
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.208991
# Linear time: 0:00:03.216946
# Increment: 76
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.254320
# Linear time: 0:00:03.263534
# Increment: 77
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.298692
# Linear time: 0:00:03.306879
# Increment: 78
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.341212
# Linear time: 0:00:03.349080
# Increment: 79
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.382460
# Linear time: 0:00:03.390423
# Increment: 80
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.425517
# Linear time: 0:00:03.433284
# Increment: 81
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.468878
# Linear time: 0:00:03.477025
# Increment: 82
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.516777
# Linear time: 0:00:03.525119
# Increment: 83
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.563623
# Linear time: 0:00:03.571879
# Increment: 84
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.610391
# Linear time: 0:00:03.618953
# Increment: 85
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.658508
# Linear time: 0:00:03.667441
# Increment: 86
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.713348
# Linear time: 0:00:03.721626
# Increment: 87
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.758649
# Linear time: 0:00:03.766921
# Increment: 88
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.813781
# Linear time: 0:00:03.823937
# Increment: 89
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.870100
# Linear time: 0:00:03.879470
# Increment: 90
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.923829
# Linear time: 0:00:03.931981
# Increment: 91
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:03.977053
# Linear time: 0:00:03.985617
# Increment: 92
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.030298
# Linear time: 0:00:04.040272
# Increment: 93
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.087718
# Linear time: 0:00:04.096924
# Increment: 94
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.145842
# Linear time: 0:00:04.155794
# Increment: 95
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.210158
# Linear time: 0:00:04.220496
# Increment: 96
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.268654
# Linear time: 0:00:04.277668
# Increment: 97
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.328003
# Linear time: 0:00:04.336731
# Increment: 98
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.389011
# Linear time: 0:00:04.397241
# Increment: 99
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.436347
# Linear time: 0:00:04.444600
# Increment: 100
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.486920
# Linear time: 0:00:04.498307
# Increment: 101
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.542120
# Linear time: 0:00:04.551467
# Increment: 102
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.590249
# Linear time: 0:00:04.598512
# Increment: 103
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.641698
# Linear time: 0:00:04.650876
# Increment: 104
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 105
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 106
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.720612
# Linear time: 0:00:04.729728
# Increment: 107
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.768411
# Linear time: 0:00:04.777324
# Increment: 108
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.813061
# Linear time: 0:00:04.821227
# Increment: 109
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.855099
# Linear time: 0:00:04.863149
# Increment: 110
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.899093
# Linear time: 0:00:04.907395
# Increment: 111
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.942486
# Linear time: 0:00:04.950313
# Increment: 112
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:04.984102
# Linear time: 0:00:04.992182
# Increment: 113
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.027006
# Linear time: 0:00:05.034784
# Increment: 114
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.069796
# Linear time: 0:00:05.077890
# Increment: 115
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.112213
# Linear time: 0:00:05.120361
# Increment: 116
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.155933
# Linear time: 0:00:05.164149
# Increment: 117
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.202648
# Linear time: 0:00:05.210885
# Increment: 118
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.247529
# Linear time: 0:00:05.255877
# Increment: 119
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.293530
# Linear time: 0:00:05.301892
# Increment: 120
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.338562
# Linear time: 0:00:05.347083
# Increment: 121
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.385443
# Linear time: 0:00:05.394001
# Increment: 122
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.435761
# Linear time: 0:00:05.448224
# Increment: 123
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.495743
# Linear time: 0:00:05.504036
# Increment: 124
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.539982
# Linear time: 0:00:05.548352
# Increment: 125
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.584449
# Linear time: 0:00:05.592774
# Increment: 126
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.628022
# Linear time: 0:00:05.636112
# Increment: 127
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.671700
# Linear time: 0:00:05.679800
# Increment: 128
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.713544
# Linear time: 0:00:05.721760
# Increment: 129
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.758219
# Linear time: 0:00:05.767997
# Increment: 130
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.806321
# Linear time: 0:00:05.814618
# Increment: 131
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.855426
# Linear time: 0:00:05.863770
# Increment: 132
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.909899
# Linear time: 0:00:05.918801
# Increment: 133
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:05.963798
# Linear time: 0:00:05.972920
# Increment: 134
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.018004
# Linear time: 0:00:06.028168
# Increment: 135
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.096129
# Linear time: 0:00:06.113287
# Increment: 136
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.181377
# Linear time: 0:00:06.191079
# Increment: 137
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.226852
# Linear time: 0:00:06.234789
# Increment: 138
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.284358
# Linear time: 0:00:06.293184
# Increment: 139
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.356838
# Linear time: 0:00:06.367589
# Increment: 140
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.411134
# Linear time: 0:00:06.421907
# Increment: 141
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.493391
# Linear time: 0:00:06.503400
# Increment: 142
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.572083
# Linear time: 0:00:06.580373
# Increment: 143
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.632508
# Linear time: 0:00:06.640923
# Increment: 144
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.681252
# Linear time: 0:00:06.689428
# Increment: 145
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.737649
# Linear time: 0:00:06.745900
# Increment: 146
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.791321
# Linear time: 0:00:06.801986
# Increment: 147
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.840851
# Linear time: 0:00:06.851783
# Increment: 148
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.893599
# Linear time: 0:00:06.901775
# Increment: 149
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:06.953886
# Linear time: 0:00:06.963825
# Increment: 150
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.025806
# Linear time: 0:00:07.036533
# Increment: 151
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.083953
# Linear time: 0:00:07.091940
# Increment: 152
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.127409
# Linear time: 0:00:07.135391
# Increment: 153
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.172665
# Linear time: 0:00:07.180787
# Increment: 154
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.218024
# Linear time: 0:00:07.226547
# Increment: 155
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 156
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 157
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 158
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.308538
# Linear time: 0:00:07.316847
# Increment: 159
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.353480
# Linear time: 0:00:07.362106
# Increment: 160
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.398222
# Linear time: 0:00:07.406267
# Increment: 161
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.444911
# Linear time: 0:00:07.452932
# Increment: 162
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.505816
# Linear time: 0:00:07.516217
# Increment: 163
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.561713
# Linear time: 0:00:07.570326
# Increment: 164
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.609162
# Linear time: 0:00:07.617210
# Increment: 165
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.653080
# Linear time: 0:00:07.661644
# Increment: 166
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.716759
# Linear time: 0:00:07.725390
# Increment: 167
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.773301
# Linear time: 0:00:07.785071
# Increment: 168
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.842679
# Linear time: 0:00:07.867294
# Increment: 169
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.939047
# Linear time: 0:00:07.948666
# Increment: 170
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:07.985388
# Linear time: 0:00:07.993626
# Increment: 171
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.029362
# Linear time: 0:00:08.037338
# Increment: 172
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.072642
# Linear time: 0:00:08.080706
# Increment: 173
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.117216
# Linear time: 0:00:08.125261
# Increment: 174
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.163147
# Linear time: 0:00:08.171525
# Increment: 175
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.207826
# Linear time: 0:00:08.215946
# Increment: 176
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.259612
# Linear time: 0:00:08.268957
# Increment: 177
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.314114
# Linear time: 0:00:08.323072
# Increment: 178
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.361262
# Linear time: 0:00:08.369233
# Increment: 179
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.412941
# Linear time: 0:00:08.423219
# Increment: 180
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.459669
# Linear time: 0:00:08.468438
# Increment: 181
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.504014
# Linear time: 0:00:08.512088
# Increment: 182
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.548260
# Linear time: 0:00:08.556233
# Increment: 183
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.590936
# Linear time: 0:00:08.598970
# Increment: 184
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.636166
# Linear time: 0:00:08.645003
# Increment: 185
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.680612
# Linear time: 0:00:08.688728
# Increment: 186
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.725361
# Linear time: 0:00:08.734259
# Increment: 187
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.770819
# Linear time: 0:00:08.779839
# Increment: 188
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.819230
# Linear time: 0:00:08.827740
# Increment: 189
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.862412
# Linear time: 0:00:08.870582
# Increment: 190
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.904863
# Linear time: 0:00:08.912583
# Increment: 191
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.947183
# Linear time: 0:00:08.955202
# Increment: 192
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:08.990320
# Linear time: 0:00:08.998366
# Increment: 193
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.035869
# Linear time: 0:00:09.047041
# Increment: 194
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.101894
# Linear time: 0:00:09.113527
# Increment: 195
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.163033
# Linear time: 0:00:09.173036
# Increment: 196
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.210094
# Linear time: 0:00:09.218450
# Increment: 197
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.259527
# Linear time: 0:00:09.267782
# Increment: 198
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.316526
# Linear time: 0:00:09.328354
# Increment: 199
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.382021
# Linear time: 0:00:09.390492
# Increment: 200
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.424464
# Linear time: 0:00:09.432576
# Increment: 201
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.467793
# Linear time: 0:00:09.475809
# Increment: 202
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.518780
# Linear time: 0:00:09.526833
# Increment: 203
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.560694
# Linear time: 0:00:09.568746
# Increment: 204
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.602973
# Linear time: 0:00:09.610930
# Increment: 205
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.646871
# Linear time: 0:00:09.655166
# Increment: 206
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.691411
# Linear time: 0:00:09.699426
# Increment: 207
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.733812
# Linear time: 0:00:09.742183
# Increment: 208
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.776841
# Linear time: 0:00:09.785002
# Increment: 209
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.820121
# Linear time: 0:00:09.828098
# Increment: 210
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.863573
# Linear time: 0:00:09.871657
# Increment: 211
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.907624
# Linear time: 0:00:09.915746
# Increment: 212
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:09.954676
# Linear time: 0:00:09.962810
# Increment: 213
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.001946
# Linear time: 0:00:10.010368
# Increment: 214
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.047252
# Linear time: 0:00:10.055367
# Increment: 215
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.091532
# Linear time: 0:00:10.099859
# Increment: 216
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.135706
# Linear time: 0:00:10.143954
# Increment: 217
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.183034
# Linear time: 0:00:10.191299
# Increment: 218
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.226774
# Linear time: 0:00:10.235043
# Increment: 219
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.271574
# Linear time: 0:00:10.279910
# Increment: 220
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.317819
# Linear time: 0:00:10.326148
# Increment: 221
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.362120
# Linear time: 0:00:10.370350
# Increment: 222
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.408715
# Linear time: 0:00:10.417247
# Increment: 223
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.456018
# Linear time: 0:00:10.464145
# Increment: 224
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.500759
# Linear time: 0:00:10.509936
# Increment: 225
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.548041
# Linear time: 0:00:10.556511
# Increment: 226
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.596281
# Linear time: 0:00:10.604858
# Increment: 227
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.642665
# Linear time: 0:00:10.650746
# Increment: 228
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.685059
# Linear time: 0:00:10.693440
# Increment: 229
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.730025
# Linear time: 0:00:10.738255
# Increment: 230
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.775754
# Linear time: 0:00:10.783932
# Increment: 231
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.819816
# Linear time: 0:00:10.827990
# Increment: 232
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.865480
# Linear time: 0:00:10.873580
# Increment: 233
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.911943
# Linear time: 0:00:10.920570
# Increment: 234
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:10.958794
# Linear time: 0:00:10.966776
# Increment: 235
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.002660
# Linear time: 0:00:11.010915
# Increment: 236
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.047222
# Linear time: 0:00:11.055184
# Increment: 237
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.090156
# Linear time: 0:00:11.098099
# Increment: 238
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.130343
# Linear time: 0:00:11.138360
# Increment: 239
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.173112
# Linear time: 0:00:11.181135
# Increment: 240
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.214973
# Linear time: 0:00:11.222934
# Increment: 241
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.257333
# Linear time: 0:00:11.265440
# Increment: 242
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.300820
# Linear time: 0:00:11.308743
# Increment: 243
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.344374
# Linear time: 0:00:11.352924
# Increment: 244
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.386056
# Linear time: 0:00:11.394037
# Increment: 245
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.427586
# Linear time: 0:00:11.435528
# Increment: 246
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.471857
# Linear time: 0:00:11.480449
# Increment: 247
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.520195
# Linear time: 0:00:11.528919
# Increment: 248
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.570049
# Linear time: 0:00:11.579664
# Increment: 249
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.628706
# Linear time: 0:00:11.636941
# Increment: 250
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.674257
# Linear time: 0:00:11.682403
# Increment: 251
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.722739
# Linear time: 0:00:11.731000
# Increment: 252
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.771295
# Linear time: 0:00:11.780705
# Increment: 253
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.821387
# Linear time: 0:00:11.829920
# Increment: 254
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.876604
# Linear time: 0:00:11.886663
# Increment: 255
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.930774
# Linear time: 0:00:11.939245
# Increment: 256
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:11.976829
# Linear time: 0:00:11.985066
# Increment: 257
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.023203
# Linear time: 0:00:12.031559
# Increment: 258
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.071430
# Linear time: 0:00:12.079761
# Increment: 259
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.117615
# Linear time: 0:00:12.125854
# Increment: 260
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.162178
# Linear time: 0:00:12.170707
# Increment: 261
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.207503
# Linear time: 0:00:12.215763
# Increment: 262
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.251712
# Linear time: 0:00:12.259767
# Increment: 263
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.296462
# Linear time: 0:00:12.304616
# Increment: 264
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.343240
# Linear time: 0:00:12.351566
# Increment: 265
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.391454
# Linear time: 0:00:12.401434
# Increment: 266
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.445552
# Linear time: 0:00:12.454422
# Increment: 267
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.495686
# Linear time: 0:00:12.504231
# Increment: 268
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.539557
# Linear time: 0:00:12.547907
# Increment: 269
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.590927
# Linear time: 0:00:12.600667
# Increment: 270
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.651670
# Linear time: 0:00:12.669735
# Increment: 271
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.714212
# Linear time: 0:00:12.723049
# Increment: 272
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.761347
# Linear time: 0:00:12.772063
# Increment: 273
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.811197
# Linear time: 0:00:12.819541
# Increment: 274
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.858962
# Linear time: 0:00:12.868524
# Increment: 275
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.923961
# Linear time: 0:00:12.932672
# Increment: 276
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:12.974547
# Linear time: 0:00:12.983904
# Increment: 277
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.022117
# Linear time: 0:00:13.030338
# Increment: 278
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.065889
# Linear time: 0:00:13.073936
# Increment: 279
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.107742
# Linear time: 0:00:13.115814
# Increment: 280
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.148714
# Linear time: 0:00:13.156591
# Increment: 281
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.191741
# Linear time: 0:00:13.200059
# Increment: 282
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.245347
# Linear time: 0:00:13.253691
# Increment: 283
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.301797
# Linear time: 0:00:13.311920
# Increment: 284
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.351553
# Linear time: 0:00:13.360124
# Increment: 285
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.403667
# Linear time: 0:00:13.413124
# Increment: 286
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.457637
# Linear time: 0:00:13.468884
# Increment: 287
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.506636
# Linear time: 0:00:13.514618
# Increment: 288
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.553204
# Linear time: 0:00:13.561265
# Increment: 289
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.600526
# Linear time: 0:00:13.610259
# Increment: 290
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.652853
# Linear time: 0:00:13.661752
# Increment: 291
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.709949
# Linear time: 0:00:13.721152
# Increment: 292
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.764022
# Linear time: 0:00:13.774255
# Increment: 293
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.827701
# Linear time: 0:00:13.839227
# Increment: 294
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.877793
# Linear time: 0:00:13.885986
# Increment: 295
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.924255
# Linear time: 0:00:13.933100
# Increment: 296
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:13.979892
# Linear time: 0:00:13.989473
# Increment: 297
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.030566
# Linear time: 0:00:14.039107
# Increment: 298
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.076322
# Linear time: 0:00:14.084767
# Increment: 299
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.121132
# Linear time: 0:00:14.129372
# Increment: 300
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.168241
# Linear time: 0:00:14.176677
# Increment: 301
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.214360
# Linear time: 0:00:14.224567
# Increment: 302
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.269541
# Linear time: 0:00:14.279531
# Increment: 303
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.329245
# Linear time: 0:00:14.346778
# Increment: 304
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.401484
# Linear time: 0:00:14.409995
# Increment: 305
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.447426
# Linear time: 0:00:14.455651
# Increment: 306
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.490903
# Linear time: 0:00:14.498783
# Increment: 307
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:14.533822
# Linear time: 0:00:14.542053
# Increment: 308
# Linear Step 1 Start
# ...
# Nonlinear time: 0:00:17.268535
# Linear time: 0:00:17.278874
# Increment: 361
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.329990
# Linear time: 0:00:17.338121
# Increment: 362
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.384872
# Linear time: 0:00:17.396948
# Increment: 363
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.442145
# Linear time: 0:00:17.451880
# Increment: 364
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.494227
# Linear time: 0:00:17.502379
# Increment: 365
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.548043
# Linear time: 0:00:17.556458
# Increment: 366
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.594313
# Linear time: 0:00:17.607892
# Increment: 367
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.652921
# Linear time: 0:00:17.664197
# Increment: 368
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.764785
# Linear time: 0:00:17.775419
# Increment: 369
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.820682
# Linear time: 0:00:17.828710
# Increment: 370
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.867340
# Linear time: 0:00:17.876208
# Increment: 371
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.919231
# Linear time: 0:00:17.929897
# Increment: 372
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:17.981827
# Linear time: 0:00:17.992704
# Increment: 373
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.041085
# Linear time: 0:00:18.052707
# Increment: 374
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.097807
# Linear time: 0:00:18.107217
# Increment: 375
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.151539
# Linear time: 0:00:18.166031
# Increment: 376
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.224593
# Linear time: 0:00:18.235535
# Increment: 377
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.291577
# Linear time: 0:00:18.306463
# Increment: 378
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.348795
# Linear time: 0:00:18.357719
# Increment: 379
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.400368
# Linear time: 0:00:18.408478
# Increment: 380
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.448886
# Linear time: 0:00:18.457537
# Increment: 381
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.495750
# Linear time: 0:00:18.504258
# Increment: 382
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.541782
# Linear time: 0:00:18.550624
# Increment: 383
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.591089
# Linear time: 0:00:18.600235
# Increment: 384
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.639426
# Linear time: 0:00:18.648358
# Increment: 385
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.685168
# Linear time: 0:00:18.693607
# Increment: 386
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.732114
# Linear time: 0:00:18.740449
# Increment: 387
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.781972
# Linear time: 0:00:18.791175
# Increment: 388
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.838925
# Linear time: 0:00:18.848094
# Increment: 389
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.886594
# Linear time: 0:00:18.895234
# Increment: 390
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.932521
# Linear time: 0:00:18.940612
# Increment: 391
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:18.975907
# Linear time: 0:00:18.983784
# Increment: 392
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.017189
# Linear time: 0:00:19.024770
# Increment: 393
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.059085
# Linear time: 0:00:19.066924
# Increment: 394
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.100619
# Linear time: 0:00:19.108791
# Increment: 395
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.144779
# Linear time: 0:00:19.152963
# Increment: 396
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.188328
# Linear time: 0:00:19.196561
# Increment: 397
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.233633
# Linear time: 0:00:19.241898
# Increment: 398
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.279230
# Linear time: 0:00:19.287071
# Increment: 399
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.321157
# Linear time: 0:00:19.328995
# Increment: 400
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.365616
# Linear time: 0:00:19.373695
# Increment: 401
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.407969
# Linear time: 0:00:19.415924
# Increment: 402
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.451118
# Linear time: 0:00:19.459142
# Increment: 403
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.495429
# Linear time: 0:00:19.503752
# Increment: 404
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.538328
# Linear time: 0:00:19.546258
# Increment: 405
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.579731
# Linear time: 0:00:19.587620
# Increment: 406
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.621099
# Linear time: 0:00:19.629347
# Increment: 407
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.666273
# Linear time: 0:00:19.674433
# Increment: 408
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.709859
# Linear time: 0:00:19.717974
# Increment: 409
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.752421
# Linear time: 0:00:19.760513
# Increment: 410
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.796353
# Linear time: 0:00:19.808752
# Increment: 411
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.863225
# Linear time: 0:00:19.871339
# Increment: 412
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.906635
# Linear time: 0:00:19.914628
# Increment: 413
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.949954
# Linear time: 0:00:19.957737
# Increment: 414
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:19.992885
# Linear time: 0:00:20.000975
# Increment: 415
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.035105
# Linear time: 0:00:20.043327
# Increment: 416
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.080346
# Linear time: 0:00:20.088395
# Increment: 417
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.123595
# Linear time: 0:00:20.131566
# Increment: 418
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.168028
# Linear time: 0:00:20.176024
# Increment: 419
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.211884
# Linear time: 0:00:20.220029
# Increment: 420
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.254631
# Linear time: 0:00:20.262810
# Increment: 421
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.296980
# Linear time: 0:00:20.305119
# Increment: 422
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.339688
# Linear time: 0:00:20.347712
# Increment: 423
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.381999
# Linear time: 0:00:20.389932
# Increment: 424
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.423510
# Linear time: 0:00:20.431418
# Increment: 425
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.465079
# Linear time: 0:00:20.473013
# Increment: 426
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.508172
# Linear time: 0:00:20.516551
# Increment: 427
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.553540
# Linear time: 0:00:20.562806
# Increment: 428
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.603286
# Linear time: 0:00:20.612407
# Increment: 429
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.651406
# Linear time: 0:00:20.659665
# Increment: 430
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.696437
# Linear time: 0:00:20.704449
# Increment: 431
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.739367
# Linear time: 0:00:20.747541
# Increment: 432
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.782786
# Linear time: 0:00:20.790648
# Increment: 433
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.826004
# Linear time: 0:00:20.834017
# Increment: 434
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.867134
# Linear time: 0:00:20.875191
# Increment: 435
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.908121
# Linear time: 0:00:20.915988
# Increment: 436
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.949848
# Linear time: 0:00:20.957780
# Increment: 437
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:20.992031
# Linear time: 0:00:20.999920
# Increment: 438
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.034246
# Linear time: 0:00:21.042260
# Increment: 439
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.076385
# Linear time: 0:00:21.084207
# Increment: 440
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.117444
# Linear time: 0:00:21.125062
# Increment: 441
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.159558
# Linear time: 0:00:21.167700
# Increment: 442
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.202382
# Linear time: 0:00:21.210164
# Increment: 443
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.245083
# Linear time: 0:00:21.253213
# Increment: 444
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.289984
# Linear time: 0:00:21.298342
# Increment: 445
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.336060
# Linear time: 0:00:21.344233
# Increment: 446
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.381418
# Linear time: 0:00:21.389276
# Increment: 447
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.427682
# Linear time: 0:00:21.435610
# Increment: 448
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.474912
# Linear time: 0:00:21.482784
# Increment: 449
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.519762
# Linear time: 0:00:21.528131
# Increment: 450
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.568256
# Linear time: 0:00:21.576485
# Increment: 451
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.616032
# Linear time: 0:00:21.624185
# Increment: 452
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.662907
# Linear time: 0:00:21.671364
# Increment: 453
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.708249
# Linear time: 0:00:21.716223
# Increment: 454
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.751131
# Linear time: 0:00:21.759076
# Increment: 455
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.796772
# Linear time: 0:00:21.805227
# Increment: 456
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.842710
# Linear time: 0:00:21.851213
# Increment: 457
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.891610
# Linear time: 0:00:21.899910
# Increment: 458
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.938007
# Linear time: 0:00:21.946571
# Increment: 459
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Number of iterations: 0
# Nonlinear time: 0:00:21.983534
# Linear time: 0:00:21.991535
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:00:21.997420
# ------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi=500)
plt.plot(results[:275, 0]/geom["longside"], results[:275, 1], "-o")

#plt.plot(results[:, 0]/geom["longside"], results[:, 3], "-o")
plt.xlabel(r"Strain [$\frac{m}{m}$]")
plt.ylabel(r"Stress [MPa]")
plt.grid()
plt.show()

# %%
results[-1,1]
# Out:
# -346628.9828767175

# %%
from matplotlib.animation import FuncAnimation, FFMpegWriter
import matplotlib.pyplot as plt
import os

plt.rcParams["animation.ffmpeg_path"] = "/usr/bin/ffmpeg"


def plot_animation(
    colors, x, y, ylabel, xlabel
):
    fig = plt.figure()
    fig.set_size_inches(7, 5)

    def animate(i):
        plt.cla()

        plt.plot(x[0:i], y[0:i], '--',linewidth=1.5)
        plt.grid(linestyle="--", linewidth=0.5, color="b")
        
        axes = fig.get_axes()[0]
        axes.set_ylabel(ylabel)
        from matplotlib.ticker import AutoMinorLocator
        
        axes.xaxis.set_minor_locator(AutoMinorLocator())
        axes.yaxis.set_minor_locator(AutoMinorLocator())
        axes.set_xlabel(xlabel)
        # ax2.plot(timeHist2[0:i], timeHist0[0:i], c=colors[0], linewidth=1.5)
        # ax2.grid(linestyle="--", linewidth=0.5, color="b")
        # ax2.set_xlabel("Time (s)")
        # ax2.set_ylabel(ylabel2)
        # from matplotlib.ticker import AutoMinorLocator

        # ax2.xaxis.set_minor_locator(AutoMinorLocator())
        # ax2.yaxis.set_minor_locator(AutoMinorLocator())

        axes.set_xlim(-.011, .011)
        axes.set_ylim(-260, 260)
        # ax2.set_ylim(-6.5, 6.6)

    set_fps = 24 
    ani = FuncAnimation(
        fig, animate, interval=1000 / set_fps, save_count=len(x)
    )

    f = r"media/Plasticity_tension.mp4"
    if not os.path.exists('media'):
        os.makedirs('media')
    writervideo = FFMpegWriter(fps=set_fps)
    ani.save(f, writer=writervideo)

# %%
plot_animation(["blue","red","green","blue"],results[:275, 0]/geom["longside"], results[:275, 1],  r"Stress [Mpa]", r"Deflection [mm]")
