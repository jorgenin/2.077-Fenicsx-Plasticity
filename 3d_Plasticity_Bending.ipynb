# %% [markdown]
# # Built In Beam in Bending

# %%
import numpy as np

import dolfinx

from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log,default_scalar_type
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem,LinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import XDMFFile, VTXWriter
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional , gt, dx, inner, derivative, dot, ln, split,TestFunction,indices,as_tensor)
from basix.ufl import element, mixed_element, quadrature_element
from datetime import datetime, timedelta
from dolfinx.plot import vtk_mesh
from dolfinx.fem.petsc import  assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc,create_matrix, create_vector
import basix
import pyvista
pyvista.set_jupyter_backend('client')

from ElasticPlasticity.Plastic_material import Plastic_Material
from ElasticPlasticity.Plastic_Visibility import Problem_Saver
from ElasticPlasticity.Plasticity_Funcs import *
from ElasticPlasticity.Plasticity_Problem import Plastic_Problem_Def

# %%
problem_name = "Plastic Bending"
# Geometric parameters
geom = {"longside" : 100.0,     # mm
        "side" : 10.0,      # mm
        "num_elements" : 5,    # size of a cell
        }


# Mechanicals parameters
mech = {"E" : 200e3,    # MPa
        "nu" : 0.3,     #       
        "sig0" : 100.0,  # MPa
        "H" : 1250.0, # MPa
        "r" : 1.0,
        "Y_s" :250.0,#mpa
        "C" : 40.0e3,
        "gamma":400.0
        
        }


# Study parameters
stud = {"deg_u" : 1,    # Interpolation of u
        "deg_strain_quad" : 2,  # Interpolation of sig, eps, p
        }

load_steps  = {
        "N_incr" : 60,  # Number of load steps
        "max_disp" : 1.0 # Maximal displacemen
        }

# %% [markdown]
# # Domain and Boundary Definition

# %%
domain = mesh.create_box(MPI.COMM_WORLD,[[0.0,0.0,0.0],[geom["longside"],geom["side"],geom["side"]]],[geom["num_elements"]*10,geom["num_elements"],geom["num_elements"]])


def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], geom["longside"])
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], geom["side"])
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], geom["side"])

boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

facet_indices, facet_markers = [], []
fdim = domain.topology.dim - 1
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator)
    facet_indices.append(facets)
    facet_markers.append(np.full_like(facets, marker))

facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
mat = Plastic_Material(domain = domain,**mech)
plastic_problem = Plastic_Problem_Def(domain,mat,facet_tags=facet_tag,**stud)

# %% [markdown]
# # Boundary Conditions

# %%
left_facets = facet_tag.find(1)

right_facets = facet_tag.find(2)


top_facets = facet_tag.find(3)
side_facets = facet_tag.find(5)
fdim = domain.topology.dim - 1
domain.topology.create_connectivity(fdim, domain.topology.dim)
disp = Constant(domain,0.0)

left_dofs_x = fem.locate_dofs_topological(plastic_problem.V, fdim, left_facets)

right_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(1),fdim, right_facets)

sym_bottom = fem.dirichletbc(np.array((0.0,0.0,0.0),dtype=default_scalar_type), left_dofs_x, plastic_problem.V)
sym_left = fem.dirichletbc(disp, right_dofs_x, plastic_problem.V.sub(1))



bcs = [sym_bottom,sym_left]

#bcs = [sym_bottom, sym_left]

#disp = Constant(domain,(0.0,0.0,0.0))


def F_ext(t):
    arr = np.zeros((3,))
    arr[1] = t*200.0
    return t*load_steps["max_disp"]

# %%
#plastic_problem._init_linear_problem([(-disp,plastic_problem.ds(2))])

# %% [markdown]
# # Data for Plotting

# %%
E_n = eps(plastic_problem.u)
E_p = plastic_problem.E_p

Stress_Point = mat.sigma(E_n - E_p)
area= Constant(domain,(geom["side"]*geom["side"]))
Elastic = Function(plastic_problem.V_scal)

project(Stress_Point[0,1],Elastic)
engineeringStress= fem.form(Elastic/area*plastic_problem.ds(2)) #P22/area*ds


pointForStress = [geom["longside"],5,5]

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, np.array(pointForStress))
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates,  np.array(pointForStress))

# %%
saver = Problem_Saver(plastic_problem,problem_name)

# %% [markdown]
# # Problem Solving

# %%
K = 25*2  # number of steps per load phase
Z = 2  # number of cycles
load, unload,load_2 = np.linspace(0.0, 1.0, num=K + 1), np.linspace(1.0, -1.0, num=K+ 1), np.linspace(-1.0, 1.0, num=K + 1)
cycle = np.concatenate((unload, load_2, unload,load_2))
cycles = np.concatenate([load]+[unload,load_2,unload])
loads = cycles

# %%
startTime = datetime.now()
Nincr = load_steps["N_incr"]

results = np.zeros((len(cycles)+1, 4))
#F = np.vectorize(F_ext)


print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

#log.set_log_level(log.LogLevel.INFO)
saver.update_and_save(0)
for (i, load) in enumerate(loads):
    # Update Diriclet boundary condition
   
    disp.value = F_ext(load)
    # Update the right hand side reusing the initial vector

    print("Increment:", str(i+1))
    niter = 0
    print("Linear Step 1 Start")
    plastic_problem.solve_linear(bcs) #Solves for the first trial displacement
    
    
    scal = fem.assemble_vector(plastic_problem.f_trial)
    print("Linear Step 1 Done")
    if scal.array.max() >= 0:
        error_0 = scal.array.max()
        niter = 0
        nls_ttime = timedelta(0,0,0)
        linear_ttime = timedelta(0,0,0)
        print("Starting Plastic Step")
        #while scal.array.max() >= 10 and niter < 20 and scal.array.max()/error_0 >.1:
           
           
        nls_time = datetime.now()
        plastic_problem.solve_nls()
        nls_ttime += datetime.now() - startTime
        linear_time = datetime.now()
        #print("Stop Plastic Step  Done")
        # print("Linear Step 2 Start")
        #f_trial = fem.assemble_scalar(fem.form(plastic_problem.res_p))
        #print(f_trial.norm())
    
        plastic_problem.solve_linear(bcs) #Solves for the actual displacement after the plastic update
        linear_ttime += datetime.now() - startTime
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
        # print("Linear Step 2 Done")
        
        #scal = fem.assemble_vector(plastic_problem.f_trial)
        #print(scal.array.max())
        #niter +=1
       # print(f"Number of iterations: {niter}")
        print(f"Nonlinear time: {nls_ttime}")
        print(f"Linear time: {linear_ttime}")
    
    
    else:
        print("Skiping Plastic Step")
        
        #vec1 = fem.assemble_vector(fem.form(plastic_problem.res_p))
        #print(plastic_problem.du.x.array)
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
    
    
    project(Stress_Point[0,1],Elastic)
    u_pointe = plastic_problem.u.eval(pointForStress,colliding_cells.array[0])[1]
    stress =  domain.comm.gather(fem.assemble_scalar(engineeringStress))[0]
    #vec2 = fem.assemble_vector(fem.form(plastic_problem.res_p))
    #print(vec1.norm())
    #print(vec2.norm())
    results[i + 1, :] = (u_pointe,stress,i+1,F_ext(load))
    
    saver.update_and_save(i)
    

print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")    
saver.close()
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Increment: 1
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 2
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 3
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 4
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 5
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 6
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 7
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 8
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 9
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 10
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 11
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 12
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 13
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 14
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 15
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 16
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 17
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 18
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 19
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:02.666379
# Linear time: 0:00:02.738246
# Increment: 20
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:02.892447
# Linear time: 0:00:02.965409
# Increment: 21
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.128638
# Linear time: 0:00:03.201045
# Increment: 22
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.356336
# Linear time: 0:00:03.436417
# Increment: 23
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.608621
# Linear time: 0:00:03.683102
# Increment: 24
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.838694
# Linear time: 0:00:03.910966
# Increment: 25
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.066974
# Linear time: 0:00:04.139587
# Increment: 26
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.292446
# Linear time: 0:00:04.364304
# Increment: 27
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.517041
# Linear time: 0:00:04.589989
# Increment: 28
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.741241
# Linear time: 0:00:04.813685
# Increment: 29
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.965056
# Linear time: 0:00:05.036845
# Increment: 30
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.186265
# Linear time: 0:00:05.259369
# Increment: 31
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.419812
# Linear time: 0:00:05.500194
# Increment: 32
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.673369
# Linear time: 0:00:05.749246
# Increment: 33
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.917487
# Linear time: 0:00:05.994036
# Increment: 34
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.161914
# Linear time: 0:00:06.235846
# Increment: 35
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.393916
# Linear time: 0:00:06.468423
# Increment: 36
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.635379
# Linear time: 0:00:06.712455
# Increment: 37
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.881578
# Linear time: 0:00:06.956592
# Increment: 38
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:07.127868
# Linear time: 0:00:07.228336
# Increment: 39
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:07.393831
# Linear time: 0:00:07.466619
# Increment: 40
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:07.624508
# Linear time: 0:00:07.697471
# Increment: 41
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:07.857016
# Linear time: 0:00:07.935015
# Increment: 42
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:08.100400
# Linear time: 0:00:08.179231
# Increment: 43
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:08.356589
# Linear time: 0:00:08.457502
# Increment: 44
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:08.718959
# Linear time: 0:00:08.796820
# Increment: 45
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:08.965602
# Linear time: 0:00:09.042638
# Increment: 46
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:09.218706
# Linear time: 0:00:09.300271
# Increment: 47
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:09.476490
# Linear time: 0:00:09.557759
# Increment: 48
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:09.716780
# Linear time: 0:00:09.790556
# Increment: 49
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:09.946861
# Linear time: 0:00:10.020093
# Increment: 50
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:10.177834
# Linear time: 0:00:10.255316
# Increment: 51
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:10.424592
# Linear time: 0:00:10.498661
# Increment: 52
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00
# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi=500)
plt.plot(results[:, 0], results[:, 1], "-o")

#plt.plot(results[:, 0]/geom["longside"], results[:, 3], "-o")
plt.ylabel(r"Stress [Mpa]")
plt.xlabel(r"Deflection [mm]")
plt.grid()
plt.show()

# %%
results[-1,1]
# Out:
# -3.6343592669693474

# %%
from matplotlib.animation import FuncAnimation, FFMpegWriter
import matplotlib.pyplot as plt
import os

plt.rcParams["animation.ffmpeg_path"] = "/usr/bin/ffmpeg"


def plot_animation(
    colors, x, y, ylabel, xlabel
):
    fig = plt.figure()
    fig.set_size_inches(7, 5)

    def animate(i):
        plt.cla()

        plt.plot(x[0:i], y[0:i], '--',linewidth=1.5)
        plt.grid(linestyle="--", linewidth=0.5, color="b")
        
        axes = fig.get_axes()[0]
        axes.set_ylabel(ylabel)
        from matplotlib.ticker import AutoMinorLocator
        
        axes.xaxis.set_minor_locator(AutoMinorLocator())
        axes.yaxis.set_minor_locator(AutoMinorLocator())
        axes.set_xlabel(xlabel)
        # ax2.plot(timeHist2[0:i], timeHist0[0:i], c=colors[0], linewidth=1.5)
        # ax2.grid(linestyle="--", linewidth=0.5, color="b")
        # ax2.set_xlabel("Time (s)")
        # ax2.set_ylabel(ylabel2)
        # from matplotlib.ticker import AutoMinorLocator

        # ax2.xaxis.set_minor_locator(AutoMinorLocator())
        # ax2.yaxis.set_minor_locator(AutoMinorLocator())

        axes.set_xlim(-1.1, 1.1)
        axes.set_ylim(-4, 4)
        # ax2.set_ylim(-6.5, 6.6)

    set_fps = 24 
    ani = FuncAnimation(
        fig, animate, interval=1000 / set_fps, save_count=len(x)
    )
    
    f = r"media/Beam_Bending.mp4"
    if not os.path.exists('media'):
        os.makedirs('media')
    
    
    writervideo = FFMpegWriter(fps=set_fps)
    ani.save(f, writer=writervideo)

# %%
plot_animation(["blue","red","green","blue"], results[:, 0], results[:, 1],  r"Stress [Mpa]", r"Deflection [mm]")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_animation(["blue","red","green","blue"], results[:, 0], results[:, 1],  r"Stress [Mpa]", r"Deflection [mm]")
#
# Cell In[15], line 51, in plot_animation(colors, x, y, ylabel, xlabel)
#      47     os.makedirs('media')
#      50 writervideo = FFMpegWriter(fps=set_fps)
# ---> 51 ani.save(f, writer=writervideo)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py:331, in MovieWriter.setup(self, fig, outfile, dpi)
#     328 self._w, self._h = self._adjust_frame_size()
#     329 # Run here so that grab_frame() can write the data to a pipe. This
#     330 # eliminates the need for temp files.
# --> 331 self._run()
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py:341, in MovieWriter._run(self)
#     338 _log.info('MovieWriter._run: running command: %s',
#     339           cbook._pformat_subprocess(command))
#     340 PIPE = subprocess.PIPE
# --> 341 self._proc = subprocess.Popen(
#     342     command, stdin=PIPE, stdout=PIPE, stderr=PIPE,
#     343     creationflags=subprocess_creation_flags)
#
# File /usr/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/lib/python3.10/subprocess.py:1863, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1861     if errno_num != 0:
#    1862         err_msg = os.strerror(errno_num)
# -> 1863     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/ffmpeg'
