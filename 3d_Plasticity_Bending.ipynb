# %% [markdown]
# # Built In Beam in Bending

# %%
import numpy as np

import dolfinx

from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log,default_scalar_type
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem,LinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import XDMFFile, VTXWriter
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional , gt, dx, inner, derivative, dot, ln, split,TestFunction,indices,as_tensor)
from basix.ufl import element, mixed_element, quadrature_element
from datetime import datetime, timedelta
from dolfinx.plot import vtk_mesh
from dolfinx.fem.petsc import  assemble_matrix, assemble_vector, apply_lifting, create_vector, set_bc,create_matrix, create_vector
import basix
import pyvista
pyvista.set_jupyter_backend('client')

from ElasticPlasticity.Plastic_material import Plastic_Material
from ElasticPlasticity.Plastic_Visibility import Problem_Saver
from ElasticPlasticity.Plasticity_Funcs import *
from ElasticPlasticity.Plasticity_Problem import Plastic_Problem_Def

# %%
problem_name = "Plastic Bending"
# Geometric parameters
geom = {"longside" : 100.0,     # mm
        "side" : 10.0,      # mm
        "num_elements" : 5,    # size of a cell
        }


# Mechanicals parameters
mech = {"E" : 200e3,    # MPa
        "nu" : 0.3,     #       
        "sig0" : 100.0,  # MPa
        "H" : 1250.0, # MPa
        "r" : 1.0,
        "Y_s" :250.0,#mpa
        "C" : 40.0e3,
        "gamma":400.0
        
        }


# Study parameters
stud = {"deg_u" : 1,    # Interpolation of u
        "deg_stress" : 2,  # Interpolation of sig, eps, p
        }

load_steps  = {
        "N_incr" : 60,  # Number of load steps
        "max_disp" : 1.0 # Maximal displacemen
        }

# %% [markdown]
# # Domain and Boundary Definition

# %%
domain = mesh.create_box(MPI.COMM_WORLD,[[0.0,0.0,0.0],[geom["longside"],geom["side"],geom["side"]]],[geom["num_elements"]*10,geom["num_elements"],geom["num_elements"]])


def xBot(x):
    return np.isclose(x[0], 0)
def xTop(x):
    return np.isclose(x[0], geom["longside"])
def yBot(x):
    return np.isclose(x[1], 0)
def yTop(x):
    return np.isclose(x[1], geom["side"])
def zBot(x):
    return np.isclose(x[2], 0)
def zTop(x):
    return np.isclose(x[2], geom["side"])

boundaries = [(1, xBot),(2,xTop),(3,yBot),(4,yTop),(5,zBot),(6,zTop)]

facet_indices, facet_markers = [], []
fdim = domain.topology.dim - 1
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator)
    facet_indices.append(facets)
    facet_markers.append(np.full_like(facets, marker))

facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
mat = Plastic_Material(domain = domain,**mech)
plastic_problem = Plastic_Problem_Def(domain,mat,facet_tags=facet_tag,**stud)

# %% [markdown]
# # Boundary Conditions

# %%
left_facets = facet_tag.find(1)

right_facets = facet_tag.find(2)


top_facets = facet_tag.find(3)
side_facets = facet_tag.find(5)
fdim = domain.topology.dim - 1
domain.topology.create_connectivity(fdim, domain.topology.dim)
disp = Constant(domain,0.0)

left_dofs_x = fem.locate_dofs_topological(plastic_problem.V, fdim, left_facets)

right_dofs_x = fem.locate_dofs_topological(plastic_problem.V.sub(1),fdim, right_facets)

sym_bottom = fem.dirichletbc(np.array((0.0,0.0,0.0),dtype=default_scalar_type), left_dofs_x, plastic_problem.V)
sym_left = fem.dirichletbc(disp, right_dofs_x, plastic_problem.V.sub(1))



bcs = [sym_bottom,sym_left]

#bcs = [sym_bottom, sym_left]

#disp = Constant(domain,(0.0,0.0,0.0))


def F_ext(t):
    arr = np.zeros((3,))
    arr[1] = t*200.0
    return t*load_steps["max_disp"]

# %%
#plastic_problem._init_linear_problem([(-disp,plastic_problem.ds(2))])

# %% [markdown]
# # Data for Plotting

# %%
E_n = eps(plastic_problem.u)
E_p = plastic_problem.E_p

Stress_Point = mat.sigma(E_n - E_p)
area= Constant(domain,(geom["side"]*geom["side"]))
Elastic = Function(plastic_problem.V_scal)

project(Stress_Point[0,1],Elastic)
engineeringStress= fem.form(Elastic/area*plastic_problem.ds(2)) #P22/area*ds


pointForStress = [geom["longside"],5,5]

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, np.array(pointForStress))
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates,  np.array(pointForStress))

# %%
saver = Problem_Saver(plastic_problem,problem_name)

# %% [markdown]
# # Problem Solving

# %%
K = 25*2  # number of steps per load phase
Z = 2  # number of cycles
load, unload,load_2 = np.linspace(0.0, 1.0, num=K + 1), np.linspace(1.0, -1.0, num=K+ 1), np.linspace(-1.0, 1.0, num=K + 1)
cycle = np.concatenate((unload, load_2, unload,load_2))
cycles = np.concatenate([load]+[unload,load_2,unload])
loads = cycles

# %%
startTime = datetime.now()
Nincr = load_steps["N_incr"]

results = np.zeros((len(cycles)+1, 4))
#F = np.vectorize(F_ext)


print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

#log.set_log_level(log.LogLevel.INFO)
saver.update_and_save(0)
for (i, load) in enumerate(loads):
    # Update Diriclet boundary condition
   
    disp.value = F_ext(load)
    # Update the right hand side reusing the initial vector

    print("Increment:", str(i+1))
    niter = 0
    print("Linear Step 1 Start")
    plastic_problem.solve_linear(bcs) #Solves for the first trial displacement
    
    
    scal = fem.assemble_vector(plastic_problem.f_trial)
    print("Linear Step 1 Done")
    if scal.array.max() >= 0:
        error_0 = scal.array.max()
        niter = 0
        nls_ttime = timedelta(0,0,0)
        linear_ttime = timedelta(0,0,0)
        print("Starting Plastic Step")
        #while scal.array.max() >= 10 and niter < 20 and scal.array.max()/error_0 >.1:
           
           
        nls_time = datetime.now()
        plastic_problem.solve_nls()
        nls_ttime += datetime.now() - startTime
        linear_time = datetime.now()
        #print("Stop Plastic Step  Done")
        # print("Linear Step 2 Start")
        #f_trial = fem.assemble_scalar(fem.form(plastic_problem.res_p))
        #print(f_trial.norm())
    
        plastic_problem.solve_linear(bcs) #Solves for the actual displacement after the plastic update
        linear_ttime += datetime.now() - startTime
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
        # print("Linear Step 2 Done")
        
        #scal = fem.assemble_vector(plastic_problem.f_trial)
        #print(scal.array.max())
        #niter +=1
       # print(f"Number of iterations: {niter}")
        print(f"Nonlinear time: {nls_ttime}")
        print(f"Linear time: {linear_ttime}")
    
    
    else:
        print("Skiping Plastic Step")
        
        #vec1 = fem.assemble_vector(fem.form(plastic_problem.res_p))
        #print(plastic_problem.du.x.array)
        plastic_problem.u.x.array[:] += plastic_problem.du.x.array[:]
        plastic_problem.du.x.array[:] = 0.0
        plastic_problem.dp.x.array[:] = 0.0
    
    
    project(Stress_Point[0,1],Elastic)
    u_pointe = plastic_problem.u.eval(pointForStress,colliding_cells.array[0])[1]
    stress =  domain.comm.gather(fem.assemble_scalar(engineeringStress))[0]
    #vec2 = fem.assemble_vector(fem.form(plastic_problem.res_p))
    #print(vec1.norm())
    #print(vec2.norm())
    results[i + 1, :] = (u_pointe,stress,i+1,F_ext(load))
    
    saver.update_and_save(i)
    

print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")    
saver.close()
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Increment: 1
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 2
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 3
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 4
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 5
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 6
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 7
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 8
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 9
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 10
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 11
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 12
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 13
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 14
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 15
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 16
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 17
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 18
# Linear Step 1 Start
# Linear Step 1 Done
# Skiping Plastic Step
# Increment: 19
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:01.779586
# Linear time: 0:00:01.847435
# Increment: 20
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:01.996424
# Linear time: 0:00:02.062772
# Increment: 21
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:02.210246
# Linear time: 0:00:02.277051
# Increment: 22
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:02.424756
# Linear time: 0:00:02.492661
# Increment: 23
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:02.641571
# Linear time: 0:00:02.709069
# Increment: 24
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:02.857023
# Linear time: 0:00:02.924540
# Increment: 25
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.071199
# Linear time: 0:00:03.137907
# Increment: 26
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.289774
# Linear time: 0:00:03.361923
# Increment: 27
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.516346
# Linear time: 0:00:03.583081
# Increment: 28
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.728907
# Linear time: 0:00:03.798897
# Increment: 29
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:03.944219
# Linear time: 0:00:04.011485
# Increment: 30
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.158968
# Linear time: 0:00:04.226222
# Increment: 31
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.374149
# Linear time: 0:00:04.442542
# Increment: 32
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.596737
# Linear time: 0:00:04.663909
# Increment: 33
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:04.807452
# Linear time: 0:00:04.874079
# Increment: 34
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.019005
# Linear time: 0:00:05.089484
# Increment: 35
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.234611
# Linear time: 0:00:05.301693
# Increment: 36
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.445651
# Linear time: 0:00:05.513191
# Increment: 37
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.662024
# Linear time: 0:00:05.730115
# Increment: 38
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:05.879760
# Linear time: 0:00:05.946173
# Increment: 39
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.097137
# Linear time: 0:00:06.163926
# Increment: 40
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.307554
# Linear time: 0:00:06.374594
# Increment: 41
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.519744
# Linear time: 0:00:06.589571
# Increment: 42
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:06.738309
# Linear time: 0:00:06.805560
# Increment: 43
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:38.661997
# Linear time: 0:00:38.730699
# Increment: 189
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:38.877606
# Linear time: 0:00:38.944660
# Increment: 190
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:39.090578
# Linear time: 0:00:39.157902
# Increment: 191
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:39.301071
# Linear time: 0:00:39.368574
# Increment: 192
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:39.511414
# Linear time: 0:00:39.579899
# Increment: 193
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:39.727665
# Linear time: 0:00:39.796761
# Increment: 194
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:39.942266
# Linear time: 0:00:40.009943
# Increment: 195
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:40.154442
# Linear time: 0:00:40.222538
# Increment: 196
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:40.368183
# Linear time: 0:00:40.435138
# Increment: 197
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:40.581412
# Linear time: 0:00:40.649628
# Increment: 198
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:40.798308
# Linear time: 0:00:40.870864
# Increment: 199
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:41.025551
# Linear time: 0:00:41.095170
# Increment: 200
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:41.247432
# Linear time: 0:00:41.317792
# Increment: 201
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:41.472458
# Linear time: 0:00:41.542160
# Increment: 202
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:41.697081
# Linear time: 0:00:41.767650
# Increment: 203
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:41.921045
# Linear time: 0:00:41.998408
# Increment: 204
# Linear Step 1 Start
# Linear Step 1 Done
# Starting Plastic Step
# Nonlinear time: 0:00:42.157509
# Linear time: 0:00:42.226694
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:00:42.241964
# ------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi=500)
plt.plot(results[:, 0], results[:, 1], "-o")

#plt.plot(results[:, 0]/geom["longside"], results[:, 3], "-o")
plt.ylabel(r"Stress [Mpa]")
plt.xlabel(r"Deflection [mm]")
plt.grid()
plt.show()

# %%
results[-1,1]
# Out:
# -3.6343592669997333

# %%
from matplotlib.animation import FuncAnimation, FFMpegWriter
import matplotlib.pyplot as plt


plt.rcParams["animation.ffmpeg_path"] = "/usr/bin/ffmpeg"


def plot_animation(
    colors, x, y, ylabel, xlabel
):
    fig = plt.figure()
    fig.set_size_inches(7, 5)

    def animate(i):
        plt.cla()

        plt.plot(x[0:i], y[0:i], '--',linewidth=1.5)
        plt.grid(linestyle="--", linewidth=0.5, color="b")
        
        axes = fig.get_axes()[0]
        axes.set_ylabel(ylabel)
        from matplotlib.ticker import AutoMinorLocator
        
        axes.xaxis.set_minor_locator(AutoMinorLocator())
        axes.yaxis.set_minor_locator(AutoMinorLocator())
        axes.set_xlabel(xlabel)
        # ax2.plot(timeHist2[0:i], timeHist0[0:i], c=colors[0], linewidth=1.5)
        # ax2.grid(linestyle="--", linewidth=0.5, color="b")
        # ax2.set_xlabel("Time (s)")
        # ax2.set_ylabel(ylabel2)
        # from matplotlib.ticker import AutoMinorLocator

        # ax2.xaxis.set_minor_locator(AutoMinorLocator())
        # ax2.yaxis.set_minor_locator(AutoMinorLocator())

        axes.set_xlim(-1.1, 1.1)
        axes.set_ylim(-4, 4)
        # ax2.set_ylim(-6.5, 6.6)

    set_fps = 24 
    ani = FuncAnimation(
        fig, animate, interval=1000 / set_fps, save_count=len(x)
    )

    f = r"media/Beam_Bending.mp4"
    writervideo = FFMpegWriter(fps=set_fps)
    ani.save(f, writer=writervideo)

# %%
plot_animation(["blue","red","green","blue"], results[:, 0], results[:, 1],  r"Stress [Mpa]", r"Deflection [mm]")
